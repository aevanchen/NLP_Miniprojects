# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import random
from collections import defaultdict
import csv

# %% [markdown]
# # Configurations

# %%
training_filename = 'train.txt'
test_filename = 'test.txt'
trial_filename = 'trial.txt'

UNKNOWN_WORD="<unk>"
SPACE=" "
GRAPH_START_STATE="pi"
graph_states = ['B-PER','B-LOC','B-ORG', 'B-MISC','I-PER','I-LOC','I-ORG', 'I-MISC','O',GRAPH_START_STATE]

# %% [markdown]
# # Tokenize and Process File

# %%
def process_file(file_name):
    with open(file_name,'r') as file:
        file_data = file.read();
        file_lines = file_data.splitlines()
                
        sentences = []
        pos_tags = []
        ner_tags = []
        
        for i in range(0,len(file_lines),3):
            sentences.append(file_lines[i].split('\t'))
            pos_tags.append(file_lines[i+1].split('\t'))
            ner_tags.append(file_lines[i+2].split('\t'))
            
        
        return sentences, pos_tags, ner_tags

# %%
sentences_trial, pos_tags_trial, ner_tags_trial  = process_file(trial_filename)

# %%
print(sentences_trial)
print(ner_tags_trial)
# Out:
# [['played', 'on', 'Monday', '(', 'home', 'team', 'in', 'CAPS', ')', ':'], ['American', 'League'], ['Cleveland', '2', 'DETROIT', '1']]
# [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['B-MISC', 'I-MISC'], ['B-ORG', 'O', 'B-ORG', 'O']]

# %% [markdown]
# # Create Training and Dev Set

# %%
sentences_tr, pos_tags_tr, ner_tags_tr = process_file(training_filename)
sentences_te, pos_tags_te, ner_tags_te = process_file(test_filename)

# %%
nTr = len(sentences_tr)
nTr
# Out:
# 14000

# %%
c=list(zip(sentences_tr, pos_tags_tr, ner_tags_tr))
random.seed(1)
random.shuffle(c)

sentences_tr, pos_tags_tr, ner_tags_tr = zip(*c)

split_point = int(0.8*nTr)

#Validation Set
sentences_val = sentences_tr[split_point:]
pos_tags_val = pos_tags_tr[split_point:]
ner_tags_val = ner_tags_tr[split_point:]


sentences_train = sentences_tr[:split_point]
pos_tags_train = pos_tags_tr[:split_point]
ner_tags_train = ner_tags_tr[:split_point]

# %% [markdown]
# # Pre-process data

# %%
def flatten_nested_lists(nested_lists):
    result = []
    
    for list_ in nested_lists:
        result+=list_
    
    return result

# %%
def preProcessIOBTagList(nested_lists):
    result = []
    
    for list_ in nested_lists:
        result.append(GRAPH_START_STATE)
        result+=list_
    
    return result

# %%
print(ner_tags_trial)
pp_ner_tags_trial = preProcessIOBTagList(ner_tags_trial)
pp_ner_tags_trial
# Out:
# [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['B-MISC', 'I-MISC'], ['B-ORG', 'O', 'B-ORG', 'O']]
# ['pi',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'pi',
#  'B-MISC',
#  'I-MISC',
#  'pi',
#  'B-ORG',
#  'O',
#  'B-ORG',
#  'O']

# %% [markdown]
# # Generic Unsmoothed N-gram Function

# %%
##################################
# Generic N-gram function
##################################
def get_N_gram_counts(N, data_list):
    if(N<=0):
        return {};
    
    n_gram_counts = {};
    
    #Form N-gram sequences
    if N>1:
        data_len = len(data_list);
        n_gram_sequence = [];
        
        for i,token in enumerate(data_list):
            if(i>=N-1):
                phrase=""
                for j in reversed(range(N-1)):
                    phrase+=data_list[i-(j+1)];
                    phrase+=SPACE;
                phrase+=token;
                n_gram_sequence.append(phrase);
                
    else:
        n_gram_sequence = data_list;
    
    #Count N-gram sequences
    for phrase in n_gram_sequence:
        if phrase in n_gram_counts.keys():
            n_gram_counts[phrase] = n_gram_counts[phrase] + 1;
        else:
            n_gram_counts[phrase] = 1;
    
    return n_gram_counts;

def get_N_gram_probabilities(N,data_list):
    if(N<=0):
        return {};
    
    n_gram_prob={};
    
    n_gram_counts = get_N_gram_counts(N,data_list);
    if(N==1):
        data_list = [token for token in data_list];
        total_num_words = len(data_list);
        n_gram_prob = { key:n_gram_counts[key]/total_num_words for key in n_gram_counts};
    else:
        n_gram_prefix_counts = get_N_gram_counts(N-1,data_list);
        n_gram_prob = { phrase:(n_gram_counts[phrase]/n_gram_prefix_counts[phrase[:phrase.rfind(" ")]])
                       for phrase in n_gram_counts.keys()}
        
        
    return n_gram_prob;


def get_N_gram_fraction(N,data_list):
    if(N<=0):
        return {};
    
    n_gram_prob={};
    
    n_gram_counts = get_N_gram_counts(N,data_list);
    if(N==1):
        data_list = [token for token in data_list if token != "<s>"];
        total_num_words = len(data_list);
        n_gram_prob = { key:(n_gram_counts[key],total_num_words) for key in n_gram_counts if key!="<s>"};
        
        
    else:
        n_gram_prefix_counts = get_N_gram_counts(N-1,data_list);
        n_gram_prob = { phrase:(n_gram_counts[phrase],n_gram_prefix_counts[phrase[:phrase.rfind(" ")]])
                       for phrase in n_gram_counts.keys()}
        
        
    return n_gram_prob;

# %%
get_N_gram_probabilities(2,pp_ner_tags_trial)
# Out:
# {'B-MISC I-MISC': 1.0,
#  'B-ORG O': 1.0,
#  'I-MISC pi': 1.0,
#  'O B-ORG': 0.08333333333333333,
#  'O O': 0.75,
#  'O pi': 0.08333333333333333,
#  'pi B-MISC': 0.3333333333333333,
#  'pi B-ORG': 0.3333333333333333,
#  'pi O': 0.3333333333333333}

# %% [markdown]
# # Kneser Ney Smoothing

# %%
def aux_lam_ds_bigram(bigram_keys):
    ds={}
    for key in bigram_keys:
        first_word = key.split()[0]
        if(first_word in ds):
            ds[first_word]+=1
        else:
            ds[first_word]=1
              
    return ds

def aux_p_continuation_ds_bigram(bigram_keys):
    ds={}
    total_bigrams=len(bigram_keys)
    for key in bigram_keys:
        second_word = key.split()[1]
        if(second_word in ds):
            ds[second_word]+=1
        else:
            ds[second_word]=1
    
    prob = {key:ds[key]/total_bigrams for key in ds.keys()}
    
    return prob
    

GENERAL_DISC_FACTOR=0.75
ZERO_DISC_FACTOR=0.5

def get_kn_abs_disc_prob_bigram(data_list):
    modified_prob = {}
    #Do not consider inputs with unknown
    bigram_counts = get_N_gram_counts(2,data_list);
    unigram_counts = get_N_gram_counts(1,data_list);
    
    total_tokens=len(data_list)
    
    discount_factor = GENERAL_DISC_FACTOR;
    
    p_cont = aux_p_continuation_ds_bigram(bigram_counts.keys())
    lam_ds = aux_lam_ds_bigram(bigram_counts.keys())
    
    for phrase in bigram_counts.keys():
        if bigram_counts[phrase] == 1:
            discount_factor=ZERO_DISC_FACTOR=0.5
        else:
            discount_factor=GENERAL_DISC_FACTOR
        first_word=phrase.split()[0];
        second_word=phrase.split()[1];
        bigram_term = max(bigram_counts[phrase] - discount_factor,0)/unigram_counts[first_word]
        lam = (discount_factor*lam_ds[first_word]) /unigram_counts[first_word]
        unigram_term = lam * p_cont[second_word]
        modified_prob[phrase]=bigram_term+unigram_term
    
    
    
    #Handle unknown outside
    modified_prob[UNKNOWN_WORD]=(0.0000027)/total_tokens;
    
    #If any word is unknown replace with unknown
    
    return modified_prob;

# %%
def aux_lam_ds_bigram_1(bigram_keys):
    ds={}
    for key in bigram_keys:
        first_word = key.split()[0]
        if(first_word in ds):
            ds[first_word]+=1
        else:
            ds[first_word]=1
              
    return ds

def aux_p_continuation_ds_bigram_1(bigram_keys):
    ds={}
    total_bigrams=len(bigram_keys)
    for key in bigram_keys:
        second_word = key.split()[1]
        if(second_word in ds):
            ds[second_word]+=1
        else:
            ds[second_word]=1
    
    prob = {key:ds[key]/total_bigrams for key in ds.keys()}
    
    return prob

def get_kn_abs_disc_prob_bigram_lex(bigram_counts, unigram_counts, vocab_len):
    modified_prob = {}
    #Do not consider inputs with unknown
    #bigram_counts = get_N_gram_counts(2,data_list);
    #unigram_counts = get_N_gram_counts(1,data_list);
    
    #total_tokens=len(data_list)
    
    discount_factor = 0.75;
    
    p_cont = aux_p_continuation_ds_bigram(bigram_counts.keys())
    lam_ds = aux_lam_ds_bigram(bigram_counts.keys())
    
    for phrase in bigram_counts.keys():
        if bigram_counts[phrase] == 1:
            discount_factor=0.5
        else:
            discount_factor=0.75
        first_word=phrase.split()[0];
        second_word=phrase.split()[1];
        bigram_term = max(bigram_counts[phrase] - discount_factor,0)/unigram_counts[first_word]
        lam = (discount_factor*lam_ds[first_word]) /unigram_counts[first_word]
        unigram_term = lam * p_cont[second_word]
        modified_prob[phrase]=bigram_term+unigram_term
    
    #Handle unknown outside
    modified_prob[UNKNOWN_WORD]=(0.0000027)/vocab_len;
    
    #If any word is unknown replace with unknown
    
    return modified_prob;

# %%
get_kn_abs_disc_prob_bigram(pp_ner_tags_trial)
# Out:
# {'<unk>': 1.4210526315789474e-07,
#  'B-MISC I-MISC': 0.5555555555555556,
#  'B-ORG O': 0.75,
#  'I-MISC pi': 0.6111111111111112,
#  'O B-ORG': 0.06944444444444445,
#  'O O': 0.75,
#  'O pi': 0.06944444444444445,
#  'pi B-MISC': 0.2222222222222222,
#  'pi B-ORG': 0.2777777777777778,
#  'pi O': 0.3333333333333333}

# %% [markdown]
# # Add-k smoothing

# %%
# Out:
#   File "<ipython-input-173-52a34e432596>", line 3
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# # Compute Probabilities/DS

# %% [markdown]
# # Compute closure of the data structures for faster access

# %%
# graph -> Represent as adjacency list { t1: { t2: score}} , also add tag for pi -> unigram prob of first word in sentence


def get_graph_states_prob(bigram_model_prob, graph_states=graph_states):
    result = {}
    for cur_state in graph_states:
        state_transition_prob = {}
        for next_state in graph_states:
            if next_state!=GRAPH_START_STATE:
                tag_sequence=cur_state+SPACE+next_state
                if tag_sequence in bigram_model_prob.keys():
                    state_transition_prob[next_state] = bigram_model_prob[tag_sequence]
                else:
                    state_transition_prob[next_state] = bigram_model_prob[UNKNOWN_WORD]
        result[cur_state] = state_transition_prob
    
    return result

# %%
#use pre-processed list so that it includes pi
bigram_model_prob = get_kn_abs_disc_prob_bigram(pp_ner_tags_trial)
print(bigram_model_prob)
get_graph_states_prob(bigram_model_prob,graph_states)
# Out:
# {'pi O': 0.3333333333333333, 'O O': 0.75, 'O pi': 0.06944444444444445, 'pi B-MISC': 0.2222222222222222, 'B-MISC I-MISC': 0.5555555555555556, 'I-MISC pi': 0.6111111111111112, 'pi B-ORG': 0.2777777777777778, 'B-ORG O': 0.75, 'O B-ORG': 0.06944444444444445, '<unk>': 1.4210526315789474e-07}
# {'B-LOC': {'B-LOC': 1.4210526315789474e-07,
#   'B-MISC': 1.4210526315789474e-07,
#   'B-ORG': 1.4210526315789474e-07,
#   'B-PER': 1.4210526315789474e-07,
#   'I-LOC': 1.4210526315789474e-07,
#   'I-MISC': 1.4210526315789474e-07,
#   'I-ORG': 1.4210526315789474e-07,
#   'I-PER': 1.4210526315789474e-07,
#   'O': 1.4210526315789474e-07},
#  'B-MISC': {'B-LOC': 1.4210526315789474e-07,
#   'B-MISC': 1.4210526315789474e-07,
#   'B-ORG': 1.4210526315789474e-07,
#   'B-PER': 1.4210526315789474e-07,
#   'I-LOC': 1.4210526315789474e-07,
#   'I-MISC': 0.5555555555555556,
#   'I-ORG': 1.4210526315789474e-07,
#   'I-PER': 1.4210526315789474e-07,
#   'O': 1.4210526315789474e-07},
#  'B-ORG': {'B-LOC': 1.4210526315789474e-07,
#   'B-MISC': 1.4210526315789474e-07,
#   'B-ORG': 1.4210526315789474e-07,
#   'B-PER': 1.4210526315789474e-07,
#   'I-LOC': 1.4210526315789474e-07,
#   'I-MISC': 1.4210526315789474e-07,
#   'I-ORG': 1.4210526315789474e-07,
#   'I-PER': 1.4210526315789474e-07,
#   'O': 0.75},
#  'B-PER': {'B-LOC': 1.4210526315789474e-07,
#   'B-MISC': 1.4210526315789474e-07,
#   'B-ORG': 1.4210526315789474e-07,
#   'B-PER': 1.4210526315789474e-07,
#   'I-LOC': 1.4210526315789474e-07,
#   'I-MISC': 1.4210526315789474e-07,
#   'I-ORG': 1.4210526315789474e-07,
#   'I-PER': 1.4210526315789474e-07,
#   'O': 1.4210526315789474e-07},
#  'I-LOC': {'B-LOC': 1.4210526315789474e-07,
#   'B-MISC': 1.4210526315789474e-07,
#   'B-ORG': 1.4210526315789474e-07,
#   'B-PER': 1.4210526315789474e-07,
#   'I-LOC': 1.4210526315789474e-07,
#   'I-MISC': 1.4210526315789474e-07,
#   'I-ORG': 1.4210526315789474e-07,
#   'I-PER': 1.4210526315789474e-07,
#   'O': 1.4210526315789474e-07},
#  'I-MISC': {'B-LOC': 1.4210526315789474e-07,
#   'B-MISC': 1.4210526315789474e-07,
#   'B-ORG': 1.4210526315789474e-07,
#   'B-PER': 1.4210526315789474e-07,
#   'I-LOC': 1.4210526315789474e-07,
#   'I-MISC': 1.4210526315789474e-07,
#   'I-ORG': 1.4210526315789474e-07,
#   'I-PER': 1.4210526315789474e-07,
#   'O': 1.4210526315789474e-07},
#  'I-ORG': {'B-LOC': 1.4210526315789474e-07,
#   'B-MISC': 1.4210526315789474e-07,
#   'B-ORG': 1.4210526315789474e-07,
#   'B-PER': 1.4210526315789474e-07,
#   'I-LOC': 1.4210526315789474e-07,
#   'I-MISC': 1.4210526315789474e-07,
#   'I-ORG': 1.4210526315789474e-07,
#   'I-PER': 1.4210526315789474e-07,
#   'O': 1.4210526315789474e-07},
#  'I-PER': {'B-LOC': 1.4210526315789474e-07,
#   'B-MISC': 1.4210526315789474e-07,
#   'B-ORG': 1.4210526315789474e-07,
#   'B-PER': 1.4210526315789474e-07,
#   'I-LOC': 1.4210526315789474e-07,
#   'I-MISC': 1.4210526315789474e-07,
#   'I-ORG': 1.4210526315789474e-07,
#   'I-PER': 1.4210526315789474e-07,
#   'O': 1.4210526315789474e-07},
#  'O': {'B-LOC': 1.4210526315789474e-07,
#   'B-MISC': 1.4210526315789474e-07,
#   'B-ORG': 0.06944444444444445,
#   'B-PER': 1.4210526315789474e-07,
#   'I-LOC': 1.4210526315789474e-07,
#   'I-MISC': 1.4210526315789474e-07,
#   'I-ORG': 1.4210526315789474e-07,
#   'I-PER': 1.4210526315789474e-07,
#   'O': 0.75},
#  'pi': {'B-LOC': 1.4210526315789474e-07,
#   'B-MISC': 0.2222222222222222,
#   'B-ORG': 0.2777777777777778,
#   'B-PER': 1.4210526315789474e-07,
#   'I-LOC': 1.4210526315789474e-07,
#   'I-MISC': 1.4210526315789474e-07,
#   'I-ORG': 1.4210526315789474e-07,
#   'I-PER': 1.4210526315789474e-07,
#   'O': 0.3333333333333333}}

# %%
def get_exhaustive_vocab():
    data_list = sentences_tr+sentences_te
    
    vocab=[]
    for word in data_list:
        #vocab
        if word not in vocab:
            vocab.append(word)

# %%
# word_tag_dict = { t1: { w1:prob, w2: prob }} 

#flatten lists before calling
def get_word_gen_prob(data_list, ner_tags, graph_states=graph_states):
    result = {}
    #Compute counts for ner_tags
    states_count = {}
    state_word_count = {} # "tag word"
    
    #Initialize all count to 0
    for state in graph_states:
        states_count[state]=0
        result[state]={}
    
    #Count occurence of tags
    for state in ner_tags:
        states_count[state]+=1
    
    
    #print(data_list)
    #print(ner_tags)
    #Count number of occurence of word
    for i,word in enumerate(data_list):
        seq = ner_tags[i]+SPACE+word
        if seq in state_word_count.keys():
            state_word_count[seq]+=1
        else:
            state_word_count[seq]=1
        
    #print(state_word_count)
    #Get smoothed bigram counts
    
    
    
    sm_prob = get_kn_abs_disc_prob_bigram_lex(state_word_count ,states_count, len(set(data_list)))
    
    
    for key in sm_prob.keys():
        if key == UNKNOWN_WORD:
            result[UNKNOWN_WORD]=sm_prob[UNKNOWN_WORD]
        else:
            result[key.split()[0]][key.split()[1]]=sm_prob[key]
    
            
    #Create exhausitive list based on vocabulary
    #for state in graph_states:
    #    for word in vocab:
    #        seq=state+SPACE+word
    #        if seq in sm_prob.keys():
    #            result[state][word]=sm_prob[seq]
    #        else:
    #            result[state][word]=sm_prob[UNKNOWN_WORD]
    
    
    return result

# %%
# word_tag_dict = { t1: { w1:prob, w2: prob }} 

#flatten lists before calling
def get_word_gen_prob(data_list, ner_tags, k=0.9, graph_states=graph_states):
    result = {}
    #Compute counts for ner_tags
    states_count = {}
    state_word_count = {} # "tag word"
    
    #Initialize all count to 0
    for state in graph_states:
        states_count[state]=0
        result[state]={}
    
    #Count occurence of tags
    for state in ner_tags:
        states_count[state]+=1
    
    
    #print(data_list)
    #print(ner_tags)
    #Count number of occurence of word
    for i,word in enumerate(data_list):
        seq = ner_tags[i]+SPACE+word
        if seq in state_word_count.keys():
            state_word_count[seq]+=1
        else:
            state_word_count[seq]=1
        
    #print(state_word_count)
    #Get smoothed bigram counts
    
    #Get vocab count
    V = len(set(data_list))
    
    #sm_prob = get_kn_abs_disc_prob_bigram_lex(state_word_count ,states_count, len(set(data_list)))
    
    for phrase in state_word_count.keys():
        tag=phrase.split()[0]
        word=phrase.split()[1]
        
        result[tag][word]= (state_word_count[word]+k)/(states_count[tag] + k*V)
    
    #to fetch in required format
    for key in sm_prob.keys():
        if key == UNKNOWN_WORD:
            result[UNKNOWN_WORD]=sm_prob[UNKNOWN_WORD]
        else:
            result[key.split()[0]][key.split()[1]]=sm_prob[key]
    
            
    #Create exhausitive list based on vocabulary
    #for state in graph_states:
    #    for word in vocab:
    #        seq=state+SPACE+word
    #        if seq in sm_prob.keys():
    #            result[state][word]=sm_prob[seq]
    #        else:
    #            result[state][word]=sm_prob[UNKNOWN_WORD]
    
    
    return result

# %%
a=[1,2]
b=[34]
a+b
# Out:
# [1, 2, 34]

# %%
flattened_sentences = flatten_nested_lists(sentences_trial)
ner_tags_sentences = flatten_nested_lists(ner_tags_trial)
get_word_gen_prob(flattened_sentences,ner_tags_sentences)
# Out:
# {'<unk>': 1.6875e-07,
#  'B-LOC': {},
#  'B-MISC': {'American': 0.53125},
#  'B-ORG': {'Cleveland': 0.28125, 'DETROIT': 0.28125},
#  'B-PER': {},
#  'I-LOC': {},
#  'I-MISC': {'League': 0.53125},
#  'I-ORG': {},
#  'I-PER': {},
#  'O': {'(': 0.07291666666666666,
#   ')': 0.07291666666666666,
#   '1': 0.07291666666666666,
#   '2': 0.07291666666666666,
#   ':': 0.07291666666666666,
#   'CAPS': 0.07291666666666666,
#   'Monday': 0.07291666666666666,
#   'home': 0.07291666666666666,
#   'in': 0.07291666666666666,
#   'on': 0.07291666666666666,
#   'played': 0.07291666666666666,
#   'team': 0.07291666666666666},
#  'pi': {}}

# %%
#This data list and ner tags needs to be preprocessed 
def get_next_tag_prob(pp_data_list, pp_ner_tags,k,V, graph_states=graph_states):
    result = {}
    
    #prev_tag_n_cur_word_counts
    bigram_counts= {}
    
    #prev_tag_cur_word_n_tag_counts
    trigram_counts= {}
    
    #Accumulate counts
    for i,word in enumerate(pp_data_list):
        if word!=GRAPH_START_STATE:
            bigram_seq=pp_ner_tags[i-1]+SPACE+word
            trigram_seq=pp_ner_tags[i-1]+SPACE+word+SPACE+pp_ner_tags[i]
            
            if bigram_seq in bigram_counts.keys():
                bigram_counts[bigram_seq]+=1
            else:
                bigram_counts[bigram_seq]=1
                
            if trigram_seq in trigram_counts.keys():
                trigram_counts[trigram_seq]+=1
            else:
                trigram_counts[trigram_seq]=1
    
    #print(trigram_counts)
    #print(bigram_counts)
    #get_kn_abs_disc_prob_bigram_lex(trigram_counts, bigram_counts, len(pp_data_list))
    
    #Cal probability    
    for key in trigram_counts.keys():
        key_list = key.split()
        
        seq_list=[key_list[0],key_list[1]]
        seq_string = key[:key.rfind(' ')]
        #print(seq_string)
        if seq_string not in result.keys():
            result[seq_string]={}
            
        result[seq_string][key_list[2]] = (trigram_counts[key] +k)/(bigram_counts[seq_string]+ k*V)
        result[seq_string]['sm_bigram_count'] = bigram_counts[seq_string]+ k*V
        
    result[UNKNOWN_WORD]=1/V
        
    
    
    return result

# %%
pp_sentences_trial=preProcessIOBTagList(sentences_trial)
pp_ner_tags_trial=preProcessIOBTagList(ner_tags_trial)
get_next_tag_prob(pp_sentences_trial,pp_ner_tags_trial,1,10)
# Out:
# {'B-MISC League': {'I-MISC': 0.18181818181818182, 'sm_bigram_count': 11},
#  'B-ORG 1': {'O': 0.18181818181818182, 'sm_bigram_count': 11},
#  'B-ORG 2': {'O': 0.18181818181818182, 'sm_bigram_count': 11},
#  'O (': {'O': 0.18181818181818182, 'sm_bigram_count': 11},
#  'O )': {'O': 0.18181818181818182, 'sm_bigram_count': 11},
#  'O :': {'O': 0.18181818181818182, 'sm_bigram_count': 11},
#  'O CAPS': {'O': 0.18181818181818182, 'sm_bigram_count': 11},
#  'O DETROIT': {'B-ORG': 0.18181818181818182, 'sm_bigram_count': 11},
#  'O Monday': {'O': 0.18181818181818182, 'sm_bigram_count': 11},
#  'O home': {'O': 0.18181818181818182, 'sm_bigram_count': 11},
#  'O in': {'O': 0.18181818181818182, 'sm_bigram_count': 11},
#  'O on': {'O': 0.18181818181818182, 'sm_bigram_count': 11},
#  'O team': {'O': 0.18181818181818182, 'sm_bigram_count': 11},
#  'pi American': {'B-MISC': 0.18181818181818182, 'sm_bigram_count': 11},
#  'pi Cleveland': {'B-ORG': 0.18181818181818182, 'sm_bigram_count': 11},
#  'pi played': {'O': 0.18181818181818182, 'sm_bigram_count': 11}}

# %%
k=1
V=len(set(flatten_nested_lists(sentences_train)))

pp_sentences_train=preProcessIOBTagList(sentences_train)
pp_ner_tags_train=preProcessIOBTagList(ner_tags_train)
get_next_tag_prob(pp_sentences_train,pp_ner_tags_train,k,V)
# Out:
# {'pi Returns': {'O': 9.202595131827176e-05},
#  'O on': {'O': 0.06003719884078031},
#  'O Treasuries': {'B-MISC': 9.202595131827176e-05},
#  'B-MISC were': {'O': 0.0003680022080132481},
#  'O also': {'O': 0.007082152974504249},
#  'O in': {'O': 0.10250691777144509},
#  'O negative': {'O': 0.0004139834406623735},
#  'O territory': {'O': 0.0003680022080132481},
#  'O at': {'O': 0.0291292498771389},
#  'O minus': {'O': 0.0002760270506509638},
#  'O 0.24': {'O': 9.202595131827176e-05},
#  'O percent': {'O': 0.011418433263579292},
#  'O ,': {'O': 0.1546331595736404},
#  'O the': {'O': 0.20599948847235924},
#  'O poorest': {'O': 0.00013803257568786233},
#  'O result': {'O': 0.0012409228789410792},
#  'O after': {'O': 0.015627831128827686},
#  'O Canada': {'B-LOC': 0.0017914561322921452},
#  'B-LOC and': {'O': 0.008350825956009857},
#  'O British': {'B-LOC': 0.0002752798678656634,
#   'B-MISC': 0.0024316388328133602,
#   'B-ORG': 0.00036703982382088455},
#  'B-MISC gilts': {'O': 0.00013803257568786233},
#  'O which': {'O': 0.01182301850757128},
#  'O lost': {'O': 0.0032565819649573433},
#  'O 0.28': {'O': 9.202595131827176e-05},
#  'O .': {'O': 0.18417990013890453},
#  'pi Skinheads': {'O': 9.202595131827176e-05},
#  'O attack': {'O': 0.0011950176954543365},
#  'O Bratislava': {'B-LOC': 0.0001840264998159735, 'O': 9.201324990798675e-05},
#  'O Rabbi': {'O': 9.202595131827176e-05},
#  'O -': {'O': 0.03443526170798898},
#  'O police': {'O': 0.005992132467294849},
#  'pi Eight': {'O': 0.0002760270506509638},
#  'O people': {'O': 0.006173968718558492},
#  'O died': {'O': 0.0014245014245014246},
#  'O Sunday': {'B-PER': 9.155832265152902e-05, 'O': 0.005127266068485625},
#  'O a': {'O': 0.0976997176548746},
#  'O blaze': {'O': 0.00013803257568786233},
#  'O Moscow': {'B-LOC': 0.0009193288899103654, 'B-ORG': 0.00022983222247759135},
#  'B-LOC casino': {'O': 9.202595131827176e-05},
#  'O fire': {'O': 0.000965428466347922},
#  'O service': {'O': 0.0012868238430074912},
#  'O said': {'O': 0.04369829255412779},
#  'O might': {'O': 0.0011950176954543365},
#  'O have': {'O': 0.0168747737965979},
#  'O been': {'O': 0.013751474993192339},
#  'O started': {'O': 0.0011950176954543365},
#  'O deliberately': {'O': 9.202595131827176e-05},
#  'O Interfax': {'B-ORG': 0.00045996044340186745},
#  'B-ORG news': {'O': 0.0010113547556658852},
#  'O agency': {'O': 0.0017456015434792595},
#  'pi "': {'O': 0.022403167034054615},
#  'O The': {'B-LOC': 0.0008235724743777453,
#   'B-ORG': 0.0002745241581259151,
#   'O': 0.004712664714494876},
#  'O defence': {'O': 0.00045996044340186745},
#  'O ministers': {'O': 0.0004139834406623735},
#  'O will': {'O': 0.011463403539098395},
#  'O begin': {'O': 0.0005059332168153804},
#  'O negotiations': {'O': 0.0010113547556658852},
#  'O for': {'O': 0.044076892623058986},
#  'O this': {'O': 0.010067419825072886},
#  'O beginning': {'O': 0.0005059332168153804},
#  'O of': {'O': 0.10949473425398516},
#  'O September': {'O': 0.0032565819649573433},
#  'O NATO': {'B-ORG': 0.0006897820288788742},
#  'B-ORG meeting': {'O': 9.202595131827176e-05},
#  'O "': {'O': 0.0498447816011543},
#  'O he': {'O': 0.020508428738844318},
#  'O told': {'O': 0.00375922614954385},
#  'O newspaper': {'O': 0.0013786131152061026},
#  'O an': {'O': 0.016830294530154277},
#  'O interview': {'O': 0.0005978660779985284},
#  'O excerpts': {'O': 9.202595131827176e-05},
#  'O were': {'O': 0.017097109774300057},
#  'O released': {'O': 0.0013786131152061026},
#  'O ahead': {'O': 0.0011950176954543365},
#  'O publication': {'O': 0.00013803257568786233},
#  'pi Guingamp': {'B-ORG': 0.0002760270506509638},
#  'B-ORG 2': {'O': 0.005673758865248227},
#  'O (': {'O': 0.03327550157925174},
#  'O Wreh': {'B-PER': 9.202595131827176e-05},
#  'B-PER 15th': {'O': 0.0001840349666436623},
#  'O 42nd': {'O': 9.202595131827176e-05},
#  'O )': {'O': 0.04023496157583252},
#  'O Monaco': {'B-ORG': 0.00023003312476996689},
#  'B-ORG 1': {'I-ORG': 9.134088417975886e-05, 'O': 0.007489952502740226},
#  'O Scifo': {'B-PER': 9.202595131827176e-05},
#  'B-PER 35th': {'O': 0.00013803257568786233},
#  'pi JYVASKYLA': {'B-LOC': 0.00013803257568786233},
#  'B-LOC ,': {'I-LOC': 8.983111749910169e-05, 'O': 0.02389507725476105},
#  'O Finland': {'B-LOC': 0.0008735632183908046},
#  'B-LOC 1996-08-24': {'O': 0.0024787697957310076},
#  'pi David': {'B-PER': 0.0003680022080132481},
#  'B-PER Prinosil': {'I-PER': 0.00013803257568786233},
#  'I-PER (': {'O': 0.056732355239170064},
#  'O Germany': {'B-LOC': 0.005081719544018678, 'B-PER': 9.156251430664286e-05},
#  'B-LOC )': {'O': 0.05079933607058618},
#  'O vs.': {'O': 0.001608012496554259},
#  'O qualifier': {'O': 0.0003220167448707333},
#  'pi Although': {'O': 0.0005978660779985284},
#  'O fake': {'O': 0.0001840349666436623},
#  'O guns': {'O': 0.0001840349666436623},
#  'O are': {'O': 0.011013516588540481},
#  'O legal': {'O': 0.0006438261669349276},
#  'O use': {'O': 0.001057276822653305},
#  'O made': {'O': 0.0032108618870694003},
#  'O them': {'O': 0.0032108618870694003},
#  'O means': {'O': 0.0005059332168153804},
#  'O could': {'O': 0.004033182089004996},
#  'O be': {'O': 0.019314951035696557},
#  'O tried': {'O': 0.0009194979541170521},
#  'O official': {'O': 0.0033937170373767485},
#  'pi The': {'B-LOC': 8.902737591809482e-05,
#   'B-MISC': 8.902737591809482e-05,
#   'B-ORG': 0.00022256843979523704,
#   'O': 0.032405964834186514},
#  'O Parisians': {'B-MISC': 9.202595131827176e-05},
#  'B-MISC ,': {'I-MISC': 9.177679882525697e-05, 'O': 0.0027533039647577094},
#  'O who': {'O': 0.01495852409228956},
#  'O yet': {'O': 0.0012868238430074912},
#  'O to': {'O': 0.1046147507210548},
#  'O concede': {'O': 9.202595131827176e-05},
#  'O goal': {'O': 0.000965428466347922},
#  'O without': {'O': 0.0013786131152061026},
#  'O Brazil': {'B-LOC': 0.0014245014245014246},
#  "B-LOC 's": {'I-LOC': 9.081002542680712e-05, 'O': 0.01325826371231384},
#  'O Leonardo': {'B-PER': 9.202595131827176e-05},
#  'B-PER and': {'O': 0.0024787697957310076},
#  'O Panama': {'B-LOC': 9.202595131827176e-05},
#  'O Julio': {'B-PER': 0.00013803257568786233},
#  'B-PER Cesar': {'I-PER': 0.00013803257568786233},
#  'I-PER Dely': {'I-PER': 9.202595131827176e-05},
#  'I-PER Valdes': {'I-PER': 9.202595131827176e-05},
#  'I-PER ,': {'O': 0.029909379045578322},
#  'O both': {'O': 0.001837306508658307},
#  'O called': {'O': 0.0016997427416391032},
#  'O up': {'O': 0.010022322445446676},
#  'O by': {'O': 0.023983831125084214},
#  'O their': {'O': 0.010878470641784252},
#  'O national': {'O': 0.0012409228789410792},
#  'O sides': {'O': 0.0005059332168153804},
#  'O leading': {'O': 0.0012868238430074912},
#  'O U.S.': {'B-LOC': 0.010364107459429974,
#   'B-MISC': 0.0009545888449474976,
#   'B-ORG': 0.0009545888449474976},
#  'B-LOC beryllium': {'O': 9.202595131827176e-05},
#  'O producer': {'O': 0.00023003312476996689},
#  'O conference': {'O': 0.001608012496554259},
#  'O call': {'O': 0.0008735632183908046},
#  'O it': {'O': 0.01922642957079027},
#  'O has': {'O': 0.012989962301857656},
#  'O traditionally': {'O': 0.0001840349666436623},
#  'O pro-active': {'O': 9.202595131827176e-05},
#  'O regarding': {'O': 0.0002760270506509638},
#  'O workplace': {'O': 9.202595131827176e-05},
#  'O disease': {'O': 0.0013786131152061026},
#  'O lung': {'O': 0.0002760270506509638},
#  'O ailment': {'O': 9.202595131827176e-05},
#  'O can': {'O': 0.002799192364170338},
#  'O affects': {'O': 0.00013803257568786233},
#  'O small': {'O': 0.0012409228789410792},
#  'O whose': {'O': 0.0010113547556658852},
#  'O immune': {'O': 0.00013803257568786233},
#  'O systems': {'O': 0.00023003312476996689},
#  'O susceptible': {'O': 9.202595131827176e-05},
#  'pi Standings': {'O': 0.0013327205882352942},
#  'O tabulate': {'O': 0.0011031946678924385},
#  'O under': {'O': 0.0050363994322604275},
#  'O played': {'O': 0.004124467256312726},
#  'O won': {'O': 0.004078826764436297},
#  'O drawn': {'O': 0.001562141052147944},
#  'O goals': {'O': 0.0021581412434566994},
#  'pi 145.4': {'O': 9.202595131827176e-05},
#  'O /': {'O': 0.0078075061638206555},
#  'O second': {'O': 0.007535622944830106},
#  'O jump': {'O': 0.0005059332168153804},
#  'O 158': {'O': 9.202595131827176e-05},
#  'pi Facing': {'O': 9.202595131827176e-05},
#  'O Yorkshire': {'B-ORG': 0.0002760270506509638},
#  "B-ORG 's": {'I-ORG': 0.0008247800586510264, 'O': 0.0034824046920821114},
#  'O 529': {'O': 9.202595131827176e-05},
#  'O eight': {'O': 0.0021581412434566994},
#  'O declared': {'O': 0.0012868238430074912},
#  'O Lancashire': {'B-ORG': 0.0002760270506509638},
#  'B-ORG were': {'O': 0.0003220167448707333},
#  'O forced': {'O': 0.0011031946678924385},
#  'O follow': {'O': 0.0001840349666436623},
#  'O 206': {'O': 9.202595131827176e-05},
#  'O behind': {'O': 0.0019748323688803158},
#  'O being': {'O': 0.0035308143800440207},
#  'O bowled': {'O': 0.0002760270506509638},
#  'O out': {'O': 0.011778080945884494},
#  'O 323': {'O': 0.00013803257568786233},
#  'O paceman': {'O': 9.202595131827176e-05},
#  'O Darren': {'B-PER': 0.0004139834406623735},
#  'B-PER Gough': {'I-PER': 0.0004139834406623735},
#  'I-PER polishing': {'O': 9.202595131827176e-05},
#  'O off': {'O': 0.004580642206037286},
#  'O innings': {'O': 0.0030736764840811085},
#  'O with': {'O': 0.026694137143369014},
#  'O burst': {'O': 0.0001840349666436623},
#  'O three': {'O': 0.00690064893519788},
#  'O wickets': {'O': 0.0014703855167026605},
#  'O one': {'O': 0.00957112255594549},
#  'O run': {'O': 0.002387182665381261},
#  'O 17': {'O': 0.002203957941135957},
#  'O deliveries': {'O': 0.0001840349666436623},
#  'pi 3': {'B-ORG': 9.198362691440924e-05, 'O': 0.0005059099480292508},
#  'O Wayne': {'B-PER': 0.0005519017614864554},
#  'B-PER Ferreira': {'I-PER': 0.0003220167448707333},
#  'O South': {'B-LOC': 0.002476382646977896,
#   'B-MISC': 0.0008254608823259653,
#   'B-ORG': 0.00022929468953499036},
#  'B-LOC Africa': {'I-LOC': 0.001883152673158185},
#  'I-LOC )': {'I-LOC': 9.172208209126347e-05, 'O': 0.003347855996331117},
#  'O beat': {'O': 0.010157602259269382},
#  'O 5': {'O': 0.0107884195193008},
#  'O Thomas': {'B-PER': 0.0007816810741217583},
#  'B-PER Enqvist': {'I-PER': 0.0002760270506509638},
#  'pi Bond': {'O': 9.202595131827176e-05},
#  'O prices': {'O': 0.002753430315267771},
#  'O weaker': {'O': 0.0005059332168153804},
#  'O and': {'O': 0.07164217361585783},
#  'O franc': {'O': 0.0001840349666436623},
#  'O was': {'O': 0.030817946659530818},
#  'O quoted': {'O': 0.0015162653923911046},
#  'O 3.4210': {'O': 9.202595131827176e-05},
#  'O per': {'O': 0.002387182665381261},
#  'O mark': {'O': 0.0005978660779985284},
#  'O first': {'O': 0.011103526734926053},
#  'O time': {'O': 0.004854146631863351},
#  'O since': {'O': 0.004398222385119347},
#  'O August': {'O': 0.002982198568544687},
#  'O 13': {'O': 0.004033182089004996},
#  'O as': {'O': 0.019093617405434686},
#  'O worries': {'O': 0.00013803257568786233},
#  'O about': {'O': 0.006492022127737393},
#  'O government': {'O': 0.006764477352712647},
#  "O 's": {'O': 0.025253431416524627},
#  'O autumn': {'O': 0.00013803257568786233},
#  'O budget': {'O': 0.0011950176954543365},
#  'O weak': {'O': 0.0003680022080132481},
#  'B-LOC currency': {'O': 9.202595131827176e-05},
#  'O lifted': {'O': 0.0004139834406623735},
#  'O squeezed': {'O': 9.202595131827176e-05},
#  'O French': {'B-LOC': 9.179786110983614e-05, 'B-MISC': 0.002524441180520494},
#  'B-MISC investments': {'O': 9.202595131827176e-05},
#  'pi Mid-tier': {'O': 9.202595131827176e-05},
#  'O golds': {'O': 9.202595131827176e-05},
#  'O heavy': {'O': 0.0005978660779985284},
#  'O trading': {'O': 0.0013327205882352942},
#  'pi Third': {'O': 0.0002760270506509638},
#  'O :': {'O': 0.022491116009176377},
#  'O 1': {'O': 0.028738714579422543},
#  'O Trent': {'B-LOC': 0.0003220167448707333},
#  'B-LOC Bridge': {'I-LOC': 0.0003220167448707333},
#  'I-LOC (': {'O': 0.0004139834406623735},
#  'O Nottingham': {'B-LOC': 0.0001840349666436623},
#  'pi Scorers': {'O': 0.0008735632183908046},
#  'O Petr': {'B-PER': 0.00023003312476996689},
#  'B-PER Gunda': {'I-PER': 9.202595131827176e-05},
#  'O 1st': {'O': 0.0001840349666436623},
#  'O 26th': {'O': 0.0001840349666436623},
#  'O Lumir': {'B-PER': 9.202595131827176e-05},
#  'B-PER Mistr': {'I-PER': 9.202595131827176e-05},
#  'O 19th': {'O': 0.0001840349666436623},
#  'pi (': {'O': 0.004580642206037286},
#  'O Haessler': {'B-PER': 9.202595131827176e-05},
#  'B-PER 33rd': {'O': 0.0001840349666436623},
#  'O Dundee': {'B-ORG': 0.00023001196062195234, 'B-PER': 0.0001380071763731714},
#  'B-PER 45th': {'O': 9.202595131827176e-05},
#  'O Keller': {'B-PER': 0.00013803257568786233},
#  'B-PER 90th': {'O': 0.00013803257568786233},
#  'pi MIAMI': {'B-LOC': 0.0001840264998159735, 'B-ORG': 9.201324990798675e-05},
#  'B-ORG 6': {'O': 0.0011950176954543365},
#  'O 7': {'O': 0.008531800346746965},
#  'O 0': {'O': 0.018872183845771818},
#  'O 285': {'O': 9.202595131827176e-05},
#  'O 266': {'O': 0.00013803257568786233},
#  'pi Groningen': {'B-ORG': 0.0003680022080132481},
#  'O Gorre': {'B-PER': 0.00013803257568786233},
#  'B-PER 66th': {'O': 0.00013803257568786233},
#  'O Roda': {'B-ORG': 0.00023003312476996689},
#  'B-ORG JC': {'I-ORG': 0.0004139834406623735},
#  'I-ORG Kerkrade': {'I-ORG': 0.0003680022080132481},
#  'I-ORG 1': {'O': 0.004033182089004996},
#  'O Vurens': {'B-PER': 9.202595131827176e-05},
#  'B-PER 3rd': {'O': 9.202595131827176e-05},
#  'pi A': {'O': 0.005582757516130509},
#  'O former': {'O': 0.0033937170373767485},
#  'O lawyer': {'O': 0.0004139834406623735},
#  'O front': {'O': 0.0006438261669349276},
#  'O line': {'O': 0.0008735632183908046},
#  'O President': {'O': 0.0028907038634486556},
#  'O Bill': {'B-PER': 0.0008735632183908046},
#  'B-PER Clinton': {'I-PER': 0.0008735632183908046},
#  "I-PER 's": {'O': 0.002844950213371266},
#  'O battle': {'O': 0.0007357336644134824},
#  'O Republican-led': {'B-MISC': 9.202595131827176e-05},
#  'B-MISC Congress': {'B-ORG': 0.00013803257568786233},
#  'B-ORG over': {'O': 9.202595131827176e-05},
#  'O but': {'O': 0.012361950643094123},
#  'O opposed': {'O': 0.0005059332168153804},
#  'O president': {'O': 0.0024787697957310076},
#  'O decision': {'O': 0.0014245014245014246},
#  'O sign': {'O': 0.0005059332168153804},
#  'O Republican-written': {'B-MISC': 9.202595131827176e-05},
#  'B-MISC welfare': {'O': 0.00013803257568786233},
#  'O reform': {'O': 0.0005978660779985284},
#  'O bill': {'O': 0.0005059332168153804},
#  'pi Over': {'O': 0.0002760270506509638},
#  'O 15-hour': {'O': 9.202595131827176e-05},
#  'O span': {'O': 0.00023003312476996689},
#  'O from': {'O': 0.024728480387756935},
#  'O evening': {'O': 0.0004139834406623735},
#  'O Monday': {'O': 0.006083058909623125},
#  'O morning': {'O': 0.0014245014245014246},
#  'O so': {'O': 0.0022497704315886133},
#  'O many': {'O': 0.0019748323688803158},
#  'O jammed': {'O': 9.202595131827176e-05},
#  'O Gore': {'B-PER': 0.0005059332168153804},
#  'B-PER events': {'O': 9.202595131827176e-05},
#  'O that': {'O': 0.02651973301079604},
#  'O marshal': {'O': 9.202595131827176e-05},
#  'O stopped': {'O': 0.0001840349666436623},
#  'O members': {'O': 0.0011950176954543365},
#  'O Congress': {'B-ORG': 0.0002760270506509638},
#  'B-ORG ,': {'I-ORG': 0.0003200731595793324, 'O': 0.006081390032007316},
#  'O reporters': {'O': 0.001608012496554259},
#  'O others': {'O': 0.0007816810741217583},
#  'O entering': {'O': 0.0004139834406623735},
#  'O pro-Israel': {'B-MISC': 9.202595131827176e-05},
#  'B-MISC rally': {'O': 0.00013803257568786233},
#  'O meeting': {'O': 0.0034394203430248554},
#  'O New': {'B-LOC': 0.003068187022026835,
#   'B-MISC': 0.0002747630168979255,
#   'B-ORG': 0.0015569904290882448,
#   'O': 9.158767229930851e-05},
#  'B-LOC York': {'I-LOC': 0.0017456015434792595},
#  'I-LOC delegation': {'O': 9.202595131827176e-05},
#  'pi 7.': {'O': 0.002203957941135957},
#  'O Ireland': {'B-LOC': 0.0011491082919654347},
#  'B-LOC 8.45': {'O': 9.202595131827176e-05},
#  'pi 18=': {'O': 0.00013803257568786233},
#  'O Miriam': {'B-PER': 0.0002760270506509638},
#  'B-PER Vogt': {'I-PER': 0.00023003312476996689},
#  'O 29': {'O': 0.0014703855167026605},
#  'pi In': {'B-ORG': 0.00013716166788588148, 'O': 0.006355157278712509},
#  'O its': {'O': 0.0107884195193008},
#  'O forecast': {'O': 0.0008735632183908046},
#  'O NWS': {'B-ORG': 9.202595131827176e-05},
#  'B-ORG said': {'O': 0.0031194091472085874},
#  'O expects': {'O': 0.00023003312476996689},
#  'O above-normal': {'O': 0.00013803257568786233},
#  'O temperatures': {'O': 0.0003220167448707333},
#  'O over': {'O': 0.009841891830318495},
#  'O lower': {'O': 0.0024787697957310076},
#  'O 48': {'O': 0.000965428466347922},
#  'O states': {'O': 0.00045996044340186745},
#  'O December': {'B-ORG': 9.189487226612754e-05, 'O': 0.0014703179562580407},
#  'O 12': {'O': 0.003622191655204035},
#  'O through': {'O': 0.002524557054989443},
#  'O 16': {'O': 0.002661893616044793},
#  'pi LOS': {'B-LOC': 9.197516670498966e-05, 'B-ORG': 0.0005978385835824328},
#  'B-ORG ANGELES': {'I-ORG': 0.0006438261669349276},
#  'I-ORG 69': {'O': 0.0001840349666436623},
#  'O 60': {'O': 0.001608012496554259},
#  'O .535': {'O': 0.0001840349666436623},
#  'pi Darlington': {'B-ORG': 0.0001840349666436623},
#  'B-ORG 3': {'O': 0.007490294587805435},
#  'O 4': {'O': 0.012989962301857656},
#  'pi +4': {'O': 0.00013803257568786233},
#  'O Stewart': {'B-PER': 0.0001840349666436623},
#  'B-PER Ginn': {'I-PER': 0.00013803257568786233},
#  'O Australia': {'B-LOC': 0.0044434264773247825,
#   'B-MISC': 9.161704076958314e-05,
#   'B-ORG': 9.161704076958314e-05},
#  'pi Women': {'O': 0.002295578715394151},
#  'O singles': {'O': 0.002203957941135957},
#  'O round': {'O': 0.003987533229443578},
#  'O This': {'O': 0.0005978660779985284},
#  'O may': {'O': 0.001837306508658307},
#  'O explain': {'O': 0.0002760270506509638},
#  'O some': {'O': 0.004808572998717714},
#  'O mistakes': {'O': 0.0002760270506509638},
#  'O against': {'O': 0.007988678900757783},
#  'O journalists': {'O': 0.0002760270506509638},
#  'O writers': {'O': 0.00013803257568786233},
#  'O longest': {'O': 0.0001840349666436623},
#  'O wait': {'O': 0.00045996044340186745},
#  'O load': {'O': 0.0003220167448707333},
#  'O West': {'B-LOC': 0.0014697776961234614,
#   'B-MISC': 0.00018372221201543268,
#   'B-ORG': 0.00018372221201543268,
#   'B-PER': 9.186110600771634e-05,
#   'O': 0.0001377916590115745},
#  'B-LOC Coast': {'I-LOC': 0.00023003312476996689},
#  'I-LOC was': {'O': 0.0002760270506509638},
#  'O days': {'O': 0.0022497704315886133},
#  'pi Constructorul': {'B-ORG': 9.202595131827176e-05},
#  'B-ORG win': {'O': 0.0002760270506509638},
#  'O away': {'O': 0.0014245014245014246},
#  'O rule': {'O': 0.0007357336644134824},
#  'B-MISC government': {'O': 0.001608012496554259},
#  'O Wednesday': {'B-ORG': 9.137844382510166e-05, 'O': 0.007081829396445379},
#  'O lowered': {'O': 0.00023003312476996689},
#  'O noise': {'O': 0.0003680022080132481},
#  'O limits': {'O': 0.0003680022080132481},
#  'O London': {'B-LOC': 0.002156655806910476, 'B-ORG': 0.0007341807002248428},
#  'O Heathrow': {'B-LOC': 0.0001840349666436623},
#  'O Gatwick': {'B-LOC': 0.00013803257568786233},
#  'O Stansted': {'B-LOC': 0.0003220167448707333},
#  'B-LOC airports': {'O': 0.0002760270506509638},
#  'O announced': {'O': 0.0014245014245014246},
#  'O would': {'O': 0.010292845106344218},
#  'O make': {'O': 0.002295578715394151},
#  'O bigger': {'O': 9.202595131827176e-05},
#  'O effort': {'O': 0.0005519017614864554},
#  'O detecting': {'O': 9.202595131827176e-05},
#  'O fining': {'O': 9.202595131827176e-05},
#  'O violators': {'O': 9.202595131827176e-05},
#  'pi Each': {'O': 0.00013803257568786233},
#  'O side': {'O': 0.000965428466347922},
#  'O scored': {'O': 0.0008276242585866017},
#  'O tries': {'O': 0.00023003312476996689},
#  'O Springboks': {'B-ORG': 9.202595131827176e-05},
#  'B-ORG outscored': {'O': 9.202595131827176e-05},
#  'O All': {'B-MISC': 9.198785760279643e-05,
#   'B-ORG': 0.00022996964400699108,
#   'O': 0.0002759635728083893},
#  'B-ORG Blacks': {'I-ORG': 0.0002760270506509638},
#  'I-ORG 15-12': {'O': 9.202595131827176e-05},
#  'O half': {'O': 0.0032565819649573433},
#  'O still': {'O': 0.002753430315267771},
#  'O suffered': {'O': 0.0006897820288788742},
#  'O fourth': {'O': 0.0011950176954543365},
#  'O successive': {'O': 0.0005059332168153804},
#  'O defeat': {'O': 0.0009194979541170521},
#  'O old': {'O': 0.0006438261669349276},
#  'O enemies': {'O': 0.0001840349666436623},
#  'pi But': {'O': 0.004580642206037286},
#  'O rally': {'O': 0.0005059332168153804},
#  'O short-lived': {'O': 9.202595131827176e-05},
#  'O Stork': {'B-ORG': 0.00013803257568786233},
#  'B-ORG ended': {'O': 9.202595131827176e-05},
#  'O just': {'O': 0.0034394203430248554},
#  'O 0.20': {'O': 0.0001840349666436623},
#  'O 51.00': {'O': 9.202595131827176e-05},
#  'O guilders': {'O': 0.0008276242585866017},
#  'pi SOFIA': {'B-LOC': 0.00023003312476996689},
#  'B-LOC 1996-12-06': {'O': 0.0049908424908424905},
#  'O In': {'B-ORG': 9.199208868037349e-05, 'O': 0.0004139643990616807},
#  'O terms': {'O': 0.0006897820288788742},
#  'O tennis': {'O': 0.0006438261669349276},
#  'O I': {'O': 0.008848346636259977},
#  'O think': {'O': 0.001883152673158185},
#  'O junior': {'O': 0.0002760270506509638},
#  'O players': {'O': 0.0017456015434792595},
#  'O really': {'O': 0.0007816810741217583},
#  'O good': {'O': 0.001883152673158185},
#  'O now': {'O': 0.002387182665381261},
#  'pi Result': {'O': 0.0012868238430074912},
#  'B-MISC first': {'O': 0.0017914561322921452},
#  'O division': {'O': 0.0019748323688803158},
#  'O match': {'O': 0.004306987399770905},
#  'O Friday': {'O': 0.010247768263800328},
#  'pi Patasse': {'B-PER': 9.202595131827176e-05},
#  'B-PER ,': {'O': 0.010382986474793934},
#  'O Central': {'B-LOC': 0.00027590012415505585,
#   'B-MISC': 9.19667080516853e-05,
#   'B-ORG': 0.00041385018623258383,
#   'B-PER': 9.19667080516853e-05},
#  'B-PER Africa': {'I-PER': 9.202595131827176e-05},
#  'O multi-party': {'O': 0.00013803257568786233},
#  'O elections': {'O': 0.0023413827931319437},
#  'O refuses': {'O': 9.202595131827176e-05},
#  'O resign': {'O': 0.0005978660779985284},
#  'pi No2': {'O': 9.202595131827176e-05},
#  'O Refined': {'O': 9.202595131827176e-05},
#  'O 75': {'O': 0.0012409228789410792},
#  'O 77': {'O': 0.0005059332168153804},
#  'O cents': {'O': 0.002661893616044793},
#  'O pound': {'O': 0.000965428466347922},
#  'pi Variable': {'O': 9.202595131827176e-05},
#  'O clouds': {'O': 9.202595131827176e-05},
#  'O southern': {'O': 0.0013786131152061026},
#  'O India': {'B-LOC': 0.0019748323688803158},
#  'B-LOC with': {'O': 0.0006897820288788742},
#  'O showers': {'O': 0.0003220167448707333},
#  'pi Auxerre': {'B-ORG': 0.0002760270506509638},
#  'O 2': {'O': 0.01980153360396933},
#  'O 3': {'O': 0.016563334389283615},
#  'pi Hapoel': {'B-ORG': 0.0003220167448707333},
#  'B-ORG Beit': {'I-ORG': 0.00013803257568786233},
#  "I-ORG She'an": {'I-ORG': 0.00013803257568786233},
#  'I-ORG 0': {'O': 0.0032565819649573433},
#  'O Hapoel': {'B-ORG': 0.00023003312476996689},
#  'pi NEW': {'B-LOC': 0.0025216633808628672, 'B-ORG': 0.0011920590527715372},
#  'B-ORG YORK': {'I-ORG': 0.0012868238430074912},
#  'I-ORG 72': {'O': 0.00013803257568786233},
#  'O 54': {'O': 0.0005978660779985284},
#  'O .571': {'O': 9.202595131827176e-05},
#  'pi Leeds': {'B-ORG': 0.0003679852805887764, 'O': 9.19963201471941e-05},
#  'B-ORG (': {'I-ORG': 0.0003215286390152037, 'O': 0.001561710532359561},
#  'O Headingley': {'B-LOC': 0.00023003312476996689},
#  'B-ORG 290': {'O': 9.202595131827176e-05},
#  'O C.': {'B-PER': 0.0004139834406623735},
#  'B-PER White': {'B-LOC': 9.199208868037349e-05,
#   'I-PER': 0.0004139643990616807},
#  'I-PER 76': {'O': 0.00013803257568786233},
#  'O M.': {'B-PER': 0.001562141052147944},
#  'B-PER Moxon': {'I-PER': 0.0002760270506509638},
#  'I-PER 59': {'O': 0.0003220167448707333},
#  'O R.': {'B-PER': 0.0004139834406623735},
#  'B-PER Blakey': {'I-PER': 0.00023003312476996689},
#  'I-PER 57': {'O': 0.0005519017614864554},
#  'O Essex': {'B-ORG': 0.00023003312476996689},
#  'B-ORG 79-2': {'O': 9.202595131827176e-05},
#  'pi Results': {'O': 0.003165137614678899},
#  'pi BELGRADE': {'B-LOC': 0.0003680022080132481},
#  'B-LOC 1996-08-29': {'O': 0.0030736764840811085},
#  'pi Until': {'O': 9.202595131827176e-05},
#  'O date': {'O': 0.0011491082919654347},
#  'O free': {'O': 0.001057276822653305},
#  'O circulation': {'O': 0.00013803257568786233},
#  'O peoples': {'O': 0.00013803257568786233},
#  'O goods': {'O': 0.0006438261669349276},
#  'O should': {'O': 0.0023413827931319437},
#  'O guaranteed': {'O': 0.0002760270506509638},
#  'O administration': {'O': 0.0003220167448707333},
#  'O installed': {'O': 0.00023003312476996689},
#  'O all': {'O': 0.005081952202179288},
#  'O areas': {'O': 0.0008276242585866017},
#  'O Unita': {'B-ORG': 0.0001840349666436623},
#  'B-ORG deputies': {'O': 9.202595131827176e-05},
#  'O occupy': {'O': 9.202595131827176e-05},
#  'O places': {'O': 0.0002760270506509638},
#  'O National': {'B-LOC': 0.0003674106732800588,
#   'B-MISC': 0.00032148433912005146,
#   'B-ORG': 0.0012859373564802058,
#   'B-PER': 9.18526683200147e-05,
#   'O': 9.18526683200147e-05},
#  'B-ORG Assembly': {'I-ORG': 0.00023003312476996689},
#  'I-ORG .': {'I-ORG': 0.00027451159811502036, 'O': 0.0055359838953195776},
#  'pi OFK': {'B-ORG': 9.202595131827176e-05},
#  'B-ORG Kikinda': {'I-ORG': 9.202595131827176e-05},
#  'O Radnicki': {'B-ORG': 9.202595131827176e-05},
#  'I-ORG N': {'I-ORG': 9.202595131827176e-05},
#  'I-ORG )': {'I-ORG': 0.00036759637917566513, 'O': 0.0011487386849239536},
#  'pi Clinton': {'B-PER': 0.0006438261669349276},
#  'B-PER to': {'O': 0.001057276822653305},
#  'O more': {'O': 0.006219417386930077},
#  'O news': {'O': 0.0017914561322921452},
#  'O conferences': {'O': 0.0001840349666436623},
#  'O 2nd': {'O': 0.0001840349666436623},
#  'O term': {'O': 0.0011031946678924385},
#  'pi LONDON': {'B-LOC': 0.003713552173115716},
#  'B-LOC 1996-08-28': {'O': 0.0038962229556288963},
#  'pi -': {'O': 0.006083058909623125},
#  'O Bosnian': {'B-MISC': 0.0008735230564111995,
#   'B-ORG': 9.194979541170521e-05},
#  'B-MISC federation': {'O': 0.00013803257568786233},
#  'O launches': {'O': 9.202595131827176e-05},
#  'O common': {'O': 0.0005059332168153804},
#  'O payment': {'O': 0.0003220167448707333},
#  'O system': {'O': 0.0009194979541170521},
#  'pi UNITED': {'B-ORG': 0.00013803257568786233},
#  'B-ORG NATIONS': {'I-ORG': 0.00013803257568786233},
#  'I-ORG 1996-12-06': {'O': 0.00023003312476996689},
#  'pi We': {'O': 0.001883152673158185},
#  "O 'll": {'O': 0.0008276242585866017},
#  'O see': {'O': 0.000965428466347922},
#  'O other': {'O': 0.004854146631863351},
#  'O produce': {'O': 0.0003680022080132481},
#  'O league': {'O': 0.0014245014245014246},
#  'O performances': {'O': 0.00013803257568786233},
#  'O play': {'O': 0.0020206659012629163},
#  'O themselves': {'O': 0.00023003312476996689},
#  'O into': {'O': 0.006083058909623125},
#  'O squad': {'O': 0.000965428466347922},
#  'pi --': {'O': 0.007172880116959064},
#  'O World': {'B-MISC': 0.0026153987335964025,
#   'B-ORG': 0.0002294209415435441,
#   'O': 0.00013765256492612646},
#  'O steel': {'O': 0.0001840349666436623},
#  'O market': {'O': 0.0052641215783209745},
#  'O shows': {'O': 0.0003220167448707333},
#  'O signs': {'O': 0.0003220167448707333},
#  'O upturn': {'O': 9.202595131827176e-05},
#  'pi Bitar': {'O': 9.202595131827176e-05},
#  'O pulled': {'O': 0.0004139834406623735},
#  'O fine': {'O': 0.0003220167448707333},
#  'O saves': {'O': 9.202595131827176e-05},
#  'O whenever': {'O': 9.202595131827176e-05},
#  'O they': {'O': 0.011238511238511238},
#  'O did': {'O': 0.0029364533149805},
#  'O Zundra': {'B-PER': 9.202595131827176e-05},
#  'B-PER Feagin': {'I-PER': 9.202595131827176e-05},
#  'O 23.18': {'O': 9.202595131827176e-05},
#  'pi It': {'O': 0.005628260272718953},
#  'O wants': {'O': 0.00045996044340186745},
#  'O hear': {'O': 0.0001840349666436623},
#  'O those': {'O': 0.001883152673158185},
#  'O committed': {'O': 0.0003680022080132481},
#  'O abuses': {'O': 0.0004139834406623735},
#  'O whom': {'O': 0.0005059332168153804},
#  'O offer': {'O': 0.0005519017614864554},
#  'O amnesty': {'O': 0.00023003312476996689},
#  'O return': {'O': 0.0015162653923911046},
#  'O frankness': {'O': 9.202595131827176e-05},
#  'pi OTTAWA': {'B-LOC': 0.00013803257568786233},
#  'pi Banco': {'B-ORG': 0.00013803257568786233},
#  'B-ORG de': {'I-ORG': 0.0001840349666436623},
#  'I-ORG Mexico': {'I-ORG': 0.0001840349666436623},
#  'I-ORG sought': {'O': 9.202595131827176e-05},
#  'O inject': {'O': 0.00013803257568786233},
#  'O 3.412': {'O': 0.00013803257568786233},
#  'O billion': {'O': 0.002387182665381261},
#  'O pesos': {'O': 0.0002760270506509638},
#  'O secondary': {'O': 0.0001840349666436623},
#  'O credit': {'O': 0.0003220167448707333},
#  'O auctions': {'O': 0.0002760270506509638},
#  'O dealers': {'O': 0.0007357336644134824},
#  'pi CYCLING': {'O': 0.00045996044340186745},
#  'O BUGNO': {'B-PER': 9.202595131827176e-05},
#  'B-PER CLEARED': {'O': 9.202595131827176e-05},
#  'O OF': {'O': 0.0015162653923911046},
#  'O DOPING': {'O': 9.202595131827176e-05},
#  'pi 8.': {'B-PER': 9.184001469440235e-05, 'O': 0.002066400330624053},
#  'O Sinead': {'B-PER': 9.202595131827176e-05},
#  'B-PER Delahunty': {'I-PER': 9.202595131827176e-05},
#  'O 4:07.27': {'O': 9.202595131827176e-05},
#  'pi Sharpe': {'B-PER': 9.202595131827176e-05},
#  'B-PER repaid': {'O': 9.202595131827176e-05},
#  'O huge': {'O': 0.0003680022080132481},
#  'O slice': {'O': 0.00013803257568786233},
#  'O 4.5': {'O': 0.0003680022080132481},
#  'O million': {'O': 0.008848346636259977},
#  'O $': {'O': 0.012361950643094123},
#  'O 6.98': {'O': 9.202595131827176e-05},
#  'O fee': {'O': 9.202595131827176e-05},
#  'O Leeds': {'B-MISC': 9.201324990798675e-05, 'B-ORG': 0.0001840264998159735},
#  'B-ORG handed': {'O': 9.202595131827176e-05},
#  'O Manchester': {'B-LOC': 0.00013799448022079117,
#   'B-ORG': 0.0003219871205151794},
#  'B-ORG United': {'I-ORG': 0.0007357336644134824},
#  'I-ORG for': {'I-ORG': 0.00022992734295962475, 'O': 0.0005058401545111745},
#  'O his': {'O': 0.01984574444093636},
#  'O services': {'O': 0.0010113547556658852},
#  'O top-draw': {'O': 9.202595131827176e-05},
#  'O second-half': {'O': 0.0001840349666436623},
#  'O hand': {'O': 0.0005978660779985284},
#  'O Wimbledon': {'B-MISC': 0.0005057238747643787,
#   'B-ORG': 0.00045974897705852605},
#  'B-ORG their': {'O': 0.00013803257568786233},
#  'O third': {'O': 0.0034394203430248554},
#  'pi Nancy': {'B-ORG': 0.0003680022080132481},
#  'B-ORG 0': {'O': 0.005400704837750012},
#  'O Paris': {'B-LOC': 0.0005977286312014345, 'B-ORG': 0.00027587475286220054},
#  'B-ORG St': {'I-ORG': 0.0003680022080132481},
#  'I-ORG Germain': {'I-ORG': 0.0003220167448707333},
#  'pi WESTERN': {'B-MISC': 0.0007357336644134824},
#  'B-MISC DIVISION': {'I-MISC': 0.002203957941135957},
#  'pi 2001': {'O': 9.202595131827176e-05},
#  'O 685,000': {'O': 9.202595131827176e-05},
#  'pi Republican': {'B-MISC': 9.202595131827176e-05},
#  'B-MISC presidential': {'O': 0.0001840349666436623},
#  'O candidate': {'O': 0.0005978660779985284},
#  'O Bob': {'B-PER': 0.0007357336644134824},
#  'B-PER Dole': {'I-PER': 0.0004139834406623735},
#  'I-PER Wednesday': {'O': 9.202595131827176e-05},
#  'O accused': {'O': 0.0011031946678924385},
#  'O Clinton': {'B-PER': 0.0019289946263721122},
#  'B-PER administration': {'O': 0.00023003312476996689},
#  'O ignoring': {'O': 0.00013803257568786233},
#  'O drug': {'O': 0.0005978660779985284},
#  'O among': {'O': 0.0005059332168153804},
#  'O teenagers': {'O': 0.00023003312476996689},
#  'O if': {'O': 0.003622191655204035},
#  'O elected': {'O': 0.0003220167448707333},
#  'B-ORG Guard': {'I-ORG': 0.00013803257568786233},
#  'I-ORG to': {'O': 0.0013786131152061026},
#  'O stop': {'O': 0.0006897820288788742},
#  'O drugs': {'O': 0.0009194979541170521},
#  'O United': {'B-LOC': 0.002430077945896378, 'B-ORG': 0.0012379642365887209},
#  'B-LOC States': {'I-LOC': 0.0023413827931319437},
#  'I-LOC .': {'O': 0.0033022978489198732},
#  'pi Kosovo': {'B-LOC': 9.202595131827176e-05},
#  'O autonomy': {'O': 0.0003680022080132481},
#  'O revoked': {'O': 9.202595131827176e-05},
#  'O 1987': {'O': 0.0002760270506509638},
#  'O Serb': {'B-MISC': 0.0005519017614864554},
#  'B-MISC police': {'O': 0.0014703855167026605},
#  'O forces': {'O': 0.0014703855167026605},
#  'O cracked': {'O': 9.202595131827176e-05},
#  'O down': {'O': 0.003713552173115716},
#  'O Albanian': {'B-MISC': 0.00045996044340186745},
#  'B-MISC protests': {'O': 9.202595131827176e-05},
#  'pi Saeed': {'B-PER': 0.0002760270506509638},
#  'B-PER Anwar': {'I-PER': 0.0005978660779985284},
#  'I-PER not': {'O': 0.0014245014245014246},
#  'O 116': {'O': 0.00013803257568786233},
#  'pi PLO': {'B-ORG': 0.0001840349666436623},
#  'B-ORG Council': {'I-ORG': 0.0005978660779985284},
#  'I-ORG calls': {'O': 9.202595131827176e-05},
#  'O halt': {'O': 0.0003220167448707333},
#  'O contacts': {'O': 0.0002760270506509638},
#  'O Israel': {'B-LOC': 0.002158042150695624, 'B-ORG': 9.183158088066487e-05},
#  'B-LOC .': {'I-LOC': 0.00022670596236681024, 'O': 0.014509181591475856},
#  'pi Ards': {'B-ORG': 0.00013803257568786233},
#  'B-ORG 10': {'I-ORG': 9.195825095406686e-05, 'O': 0.0007816451331095683},
#  'O 11': {'O': 0.003987533229443578},
#  'pi Madison': {'B-LOC': 9.202595131827176e-05},
#  'B-LOC final': {'O': 9.202595131827176e-05},
#  'O 50': {'O': 0.0020664952240999263},
#  'O kms': {'O': 0.0003220167448707333},
#  'O Elena': {'B-PER': 0.0001840349666436623},
#  'B-PER Koroleva': {'I-PER': 0.00013803257568786233},
#  'O Russia': {'B-LOC': 0.003210714613338226, 'B-ORG': 9.173470323823502e-05},
#  'O 21.77': {'O': 9.202595131827176e-05},
#  'pi Italian': {'B-MISC': 0.00045996044340186745},
#  'B-MISC farmer': {'O': 9.202595131827176e-05},
#  'O says': {'O': 0.001057276822653305},
#  'O mutilated': {'O': 0.00013803257568786233},
#  'O four': {'O': 0.004352606982497938},
#  'O women': {'O': 0.0019748323688803158},
#  'pi World': {'B-MISC': 0.0003219575016097875,
#   'B-ORG': 9.198785760279643e-05,
#   'O': 0.00018397571520559287},
#  'B-MISC Cup': {'B-MISC': 9.1755746203606e-05, 'I-MISC': 0.002982061751617195},
#  'I-MISC ski': {'O': 9.202595131827176e-05},
#  'O officials': {'O': 0.0030736764840811085},
#  'O hope': {'O': 0.0008735632183908046},
#  'O able': {'O': 0.0009194979541170521},
#  'O get': {'O': 0.0017914561322921452},
#  'O least': {'O': 0.0011950176954543365},
#  'O men': {'O': 0.0015162653923911046},
#  'O downhill': {'O': 0.00023003312476996689},
#  'O training': {'O': 0.0005059332168153804},
#  'O Saturday': {'O': 0.005628260272718953},
#  'O salvage': {'O': 0.00013803257568786233},
#  'O weekend': {'O': 0.0013786131152061026},
#  'O racing': {'O': 0.0002760270506509638},
#  'O programme': {'O': 0.0007357336644134824},
#  'pi 3.': {'O': 0.003165137614678899},
#  'O Bartoli': {'B-PER': 9.202595131827176e-05},
#  'B-PER 108': {'O': 0.00013803257568786233},
#  'pi the': {'O': 0.0003220167448707333},
#  'O held': {'O': 0.002661893616044793},
#  'O 14': {'O': 0.0041701035652094215},
#  'O OSCE': {'B-ORG': 0.0005978660779985284},
#  'B-ORG spokeswoman': {'O': 0.00013803257568786233},
#  'O Agota': {'B-PER': 9.202595131827176e-05},
#  'B-PER Kuperman': {'I-PER': 9.202595131827176e-05},
#  'I-PER told': {'O': 0.0014703855167026605},
#  'O Sarajevo': {'B-LOC': 0.0002760270506509638},
#  'O separatists': {'O': 0.0002760270506509638},
#  'O take': {'O': 0.0033022978489198732},
#  'O advantage': {'O': 0.0005519017614864554},
#  'O social': {'O': 0.0003680022080132481},
#  'O unrest': {'O': 0.0004139834406623735},
#  'O widely': {'O': 0.0002760270506509638},
#  'O expected': {'O': 0.0033480095395340306},
#  'O mainland': {'O': 0.00023003312476996689},
#  'O coming': {'O': 0.0011491082919654347},
#  'O weeks': {'O': 0.0019289946263721122},
#  'O austerity': {'O': 0.00013803257568786233},
#  'O plans': {'O': 0.0013327205882352942},
#  'O stoke': {'O': 9.202595131827176e-05},
#  'O popular': {'O': 0.0004139834406623735},
#  'O backlash': {'O': 9.202595131827176e-05},
#  'O biggest': {'O': 0.0005519017614864554},
#  'O success': {'O': 0.0002760270506509638},
#  'O Viacom': {'B-MISC': 9.202595131827176e-05},
#  'B-MISC Inc-owned': {'I-MISC': 9.202595131827176e-05},
#  'I-MISC Paramount': {'B-ORG': 9.202595131827176e-05},
#  'B-ORG since': {'O': 0.00013803257568786233},
#  'O 1994': {'O': 0.0013327205882352942},
#  'O Forrest': {'B-MISC': 9.202595131827176e-05},
#  'B-MISC Gump': {'I-MISC': 9.202595131827176e-05},
#  'I-MISC "': {'O': 0.0006897820288788742},
#  'pi 1.': {'O': 0.0033480095395340306},
#  'O Ray': {'B-PER': 0.0001840349666436623},
#  'B-PER Belim': {'I-PER': 9.202595131827176e-05},
#  'O Britain': {'B-LOC': 0.0038962229556288963},
#  'O James': {'B-PER': 0.0003680022080132481},
#  'B-PER Weaver': {'I-PER': 0.0001840349666436623},
#  'O J.J.Lehto': {'O': 9.202595131827176e-05},
#  'pi CHICAGO': {'B-LOC': 0.0007350576560848992,
#   'B-ORG': 0.0009647631736114301},
#  'B-ORG AT': {'O': 0.00375922614954385},
#  'O HOUSTON': {'B-LOC': 0.0004139072847682119, 'B-ORG': 0.0002299484915378955},
#  'pi 9.': {'O': 0.0016997427416391032},
#  'O Corser': {'B-PER': 0.0003220167448707333},
#  'B-PER 38:42.015': {'O': 0.00013803257568786233},
#  'pi 2.': {'O': 0.0033480095395340306},
#  'O Andrea': {'B-PER': 0.0004139834406623735},
#  'B-PER Collinelli': {'I-PER': 0.00023003312476996689},
#  'O Italy': {'B-LOC': 0.004626236716746061},
#  'O 4:17.696': {'O': 9.202595131827176e-05},
#  'pi LISBON': {'B-LOC': 0.0002760270506509638},
#  'B-LOC 1996-08-25': {'O': 0.002295578715394151},
#  'pi Lyon': {'B-ORG': 0.0001840349666436623},
#  'B-ORG 4': {'O': 0.0041701035652094215},
#  'O 6': {'O': 0.009706525701786366},
#  'pi He': {'O': 0.007127518618357929},
#  'O co-driver': {'O': 9.202595131827176e-05},
#  'O Derek': {'B-PER': 0.0002760270506509638},
#  'B-PER Ringer': {'I-PER': 9.202595131827176e-05},
#  'I-PER were': {'O': 0.0004139834406623735},
#  'O unhurt': {'O': 0.00013803257568786233},
#  'O team': {'O': 0.002524557054989443},
#  'O boss': {'O': 0.0002760270506509638},
#  'O David': {'B-LOC': 9.189065012634965e-05, 'B-PER': 0.001516195727084769},
#  'B-PER Richards': {'I-PER': 0.00013803257568786233},
#  'I-PER was': {'O': 0.0017456015434792595},
#  'O furious': {'O': 9.202595131827176e-05},
#  'pi after': {'O': 9.202595131827176e-05},
#  'O opening': {'O': 0.0011031946678924385},
#  'O practice': {'O': 0.00013803257568786233},
#  'O sessions': {'O': 0.00013803257568786233},
#  'I-ORG AT': {'O': 0.000965428466347922},
#  'O LOS': {'B-LOC': 0.00013802622498274673, 'B-ORG': 9.201748332183115e-05},
#  'B-LOC ANGELES': {'I-LOC': 0.0001840349666436623},
#  'pi CENTRAL': {'B-MISC': 0.0008276242585866017},
#  'pi Played': {'O': 0.0005978660779985284},
#  'pi Soybeans': {'O': 0.00013803257568786233},
#  'O 283': {'O': 0.00013803257568786233},
#  'O unq': {'O': 0.000965428466347922},
#  'pi Club': {'B-ORG': 9.202595131827176e-05},
#  'B-ORG Brugge': {'I-ORG': 0.0002760270506509638},
#  'I-ORG 4': {'O': 0.002799192364170338},
#  'O 10': {'O': 0.006537441711621103},
#  'O 8': {'O': 0.0049908424908424905},
#  'O Those': {'O': 9.202595131827176e-05},
#  'O little': {'O': 0.001057276822653305},
#  'O seconds': {'O': 0.0032108618870694003},
#  'O like': {'O': 0.0013327205882352942},
#  'O hour': {'O': 0.0005519017614864554},
#  'O me': {'O': 0.0013786131152061026},
#  'O Oncins': {'B-PER': 0.0003680022080132481},
#  'O promptly': {'O': 0.00013803257568786233},
#  'O fired': {'O': 0.0005978660779985284},
#  'O two': {'O': 0.012586332242820792},
#  'O serves': {'O': 0.00013803257568786233},
#  'O barely': {'O': 0.00013803257568786233},
#  'O contained': {'O': 0.0001840349666436623},
#  'O baseline': {'O': 9.202595131827176e-05},
#  'O frittered': {'O': 9.202595131827176e-05},
#  'O best': {'O': 0.0011950176954543365},
#  'O chance': {'O': 0.0009194979541170521},
#  'pi Division': {'O': 0.0007357336644134824},
#  'O GT2': {'B-MISC': 0.0001840349666436623},
#  'B-MISC Roock': {'I-MISC': 9.202595131827176e-05},
#  'I-MISC Porsche': {'I-MISC': 0.00013803257568786233},
#  'I-MISC 911': {'I-MISC': 0.00013803257568786233},
#  'I-MISC 164': {'O': 0.00013803257568786233},
#  'pi division': {'O': 0.0005519017614864554},
#  'O soccer': {'O': 0.0012409228789410792},
#  'pi SOCCER': {'O': 0.004717413208756985},
#  'O EUROPEAN': {'B-MISC': 0.0003220167448707333},
#  'B-MISC CUP': {'I-MISC': 0.0007357336644134824},
#  'I-MISC DRAWS': {'O': 9.202595131827176e-05},
#  'O FOR': {'O': 0.0005519017614864554},
#  'O AEK': {'B-ORG': 0.00013803257568786233},
#  'O OLYMPIAKOS': {'B-ORG': 0.0001840349666436623},
#  'O PAO': {'B-ORG': 9.202595131827176e-05},
#  'B-ORG .': {'O': 0.005946663007181739},
#  'pi Argentine': {'B-MISC': 0.00023003312476996689},
#  'B-MISC raw': {'O': 9.202595131827176e-05},
#  'O output': {'O': 0.0006438261669349276},
#  'O 355,900': {'O': 9.202595131827176e-05},
#  'O tonnes': {'O': 0.0029364533149805},
#  'O July': {'O': 0.0032565819649573433},
#  'O 14.8': {'O': 0.00013803257568786233},
#  'O higher': {'O': 0.0012868238430074912},
#  'O than': {'O': 0.005309653499336293},
#  'O 1995': {'O': 0.00270766406608536},
#  'O 1.9': {'O': 0.00013803257568786233},
#  'O June': {'O': 0.002799192364170338},
#  'O Steel': {'B-ORG': 9.202595131827176e-05},
#  'B-ORG Industry': {'I-ORG': 0.00013803257568786233},
#  'I-ORG Center': {'I-ORG': 9.202595131827176e-05},
#  'I-ORG said': {'O': 0.003941880185176697},
#  'O Thursday': {'O': 0.010022322445446676},
#  'pi Cruise': {'B-PER': 9.202595131827176e-05},
#  'B-PER will': {'O': 0.0005059332168153804},
#  'O reprise': {'O': 9.202595131827176e-05},
#  'O roles': {'O': 9.202595131827176e-05},
#  'O star': {'O': 0.00013803257568786233},
#  'O co-producer': {'O': 9.202595131827176e-05},
#  'O soon': {'O': 0.0007357336644134824},
#  'O meet': {'O': 0.0022497704315886133},
#  'O Academy': {'B-MISC': 9.202595131827176e-05},
#  'B-MISC Award-winning': {'I-MISC': 9.202595131827176e-05},
#  'I-MISC screenwriter': {'O': 9.202595131827176e-05},
#  'O William': {'B-PER': 0.0003220167448707333},
#  'B-PER Goldman': {'I-PER': 9.202595131827176e-05},
#  'O write': {'O': 0.0001840349666436623},
#  'O script': {'O': 9.202595131827176e-05},
#  'O report': {'O': 0.0019748323688803158},
#  'pi Zaire': {'B-LOC': 9.202595131827176e-05},
#  'B-LOC is': {'O': 0.0012409228789410792},
#  'O home': {'O': 0.003485119457055074},
#  'O 1.1': {'O': 0.0001840349666436623},
#  'O Rwandan': {'B-MISC': 0.0004139834406623735},
#  'B-MISC Hutu': {'B-MISC': 0.00013803257568786233},
#  'B-MISC refugees': {'O': 0.0005059332168153804},
#  'O fled': {'O': 0.0003680022080132481},
#  'O months': {'O': 0.0019289946263721122},
#  'O civil': {'O': 0.0005059332168153804},
#  'O war': {'O': 0.0019289946263721122},
#  'O protests': {'O': 0.0005978660779985284},
#  'O contributed': {'O': 0.00013803257568786233},
#  'O seen': {'O': 0.0016997427416391032},
#  'O primarily': {'O': 0.00013803257568786233},
#  'O economic': {'O': 0.001562141052147944},
#  'O rather': {'O': 0.00045996044340186745},
#  'O ecological': {'O': 9.202595131827176e-05},
#  'O GLORIA': {'B-ORG': 9.202595131827176e-05},
#  'B-ORG BISTRITA': {'I-ORG': 9.202595131827176e-05},
#  'I-ORG BEAT': {'O': 9.202595131827176e-05},
#  'O 2-1': {'O': 0.0009194979541170521},
#  'O F.C.': {'B-ORG': 0.0001840349666436623},
#  'B-ORG VALLETTA': {'I-ORG': 9.202595131827176e-05},
#  'pi Testing': {'O': 9.202595131827176e-05},
#  'O begun': {'O': 0.00045996044340186745},
#  'O results': {'O': 0.002524557054989443},
#  'O within': {'O': 0.0008735632183908046},
#  'O next': {'O': 0.00375922614954385},
#  'O several': {'O': 0.0017914561322921452},
#  'O Arch': {'B-ORG': 0.00013803257568786233},
#  'pi )': {'O': 0.00013803257568786233},
#  'O 0-0': {'O': 0.0008276242585866017},
#  'O GERMAN': {'B-MISC': 0.0006897820288788742},
#  'B-MISC FIRST': {'O': 0.0013327205882352942},
#  'O DIVISION': {'B-PER': 9.187798603454613e-05, 'O': 0.0016538037486218302},
#  'O RESULTS': {'O': 0.0030736764840811085},
#  'pi Armoured': {'O': 9.202595131827176e-05},
#  'O cars': {'O': 0.0003680022080132481},
#  'O had': {'O': 0.016919249038679033},
#  'O patrolled': {'O': 0.0001840349666436623},
#  'O streets': {'O': 0.0005059332168153804},
#  'O Karak': {'B-LOC': 0.00013803257568786233},
#  'O traditional': {'O': 0.00023003312476996689},
#  'O bastion': {'O': 9.202595131827176e-05},
#  'O communist': {'O': 0.00045996044340186745},
#  'O ideology': {'O': 9.202595131827176e-05},
#  'O Baath': {'B-MISC': 9.202595131827176e-05},
#  'B-MISC socialism': {'O': 9.202595131827176e-05},
#  'O swept': {'O': 0.00013803257568786233},
#  'O region': {'O': 0.0012868238430074912},
#  'O 1950s': {'O': 9.202595131827176e-05},
#  'O guarded': {'O': 0.0001840349666436623},
#  'O entrances': {'O': 9.202595131827176e-05},
#  'O hill-top': {'O': 9.202595131827176e-05},
#  'O city': {'O': 0.0019748323688803158},
#  'O famed': {'O': 0.00013803257568786233},
#  'O Crusader': {'O': 9.202595131827176e-05},
#  'O castle': {'O': 9.202595131827176e-05},
#  'O before': {'O': 0.004762995191206778},
#  'O prayers': {'O': 0.0002760270506509638},
#  'pi At': {'O': 0.002753430315267771},
#  'O convention': {'O': 0.0007357336644134824},
#  'O years': {'O': 0.004535043518094366},
#  'O ago': {'O': 0.002524557054989443},
#  'O organizers': {'O': 9.202595131827176e-05},
#  'O prevented': {'O': 0.00023003312476996689},
#  'O then': {'O': 0.0024329783327212634},
#  'O Pennsylvania': {'B-LOC': 0.00013803257568786233},
#  'B-LOC Gov': {'O': 9.202595131827176e-05},
#  'pi Thomas': {'B-PER': 0.0001840349666436623},
#  'B-PER Johansson': {'I-PER': 0.00013803257568786233},
#  'O Sweden': {'B-LOC': 0.0022497704315886133},
#  'O Renzo': {'B-PER': 0.00013803257568786233},
#  'B-PER Furlan': {'I-PER': 0.00013803257568786233},
#  'O 4-6': {'O': 0.0006897820288788742},
#  'O 2-6': {'O': 0.0008735632183908046},
#  'O 7-5': {'O': 0.0023413827931319437},
#  'pi Opinion': {'O': 9.202595131827176e-05},
#  'O polls': {'O': 0.0004139834406623735},
#  'O consistently': {'O': 9.202595131827176e-05},
#  'O show': {'O': 0.0005059332168153804},
#  'B-MISC voters': {'O': 9.202595131827176e-05},
#  'O pessimistic': {'O': 9.202595131827176e-05},
#  'O fed': {'O': 0.00023003312476996689},
#  'O economy': {'O': 0.0011031946678924385},
#  'O stagnates': {'O': 9.202595131827176e-05},
#  'O unemployement': {'O': 9.202595131827176e-05},
#  'O lingers': {'O': 0.00013803257568786233},
#  'O near-record': {'O': 9.202595131827176e-05},
#  'O levels': {'O': 0.0011031946678924385},
#  'O number': {'O': 0.0021581412434566994},
#  'O Rodney': {'B-PER': 0.00013803257568786233},
#  'B-PER Eyles': {'I-PER': 0.00013803257568786233},
#  'I-PER moved': {'O': 9.202595131827176e-05},
#  'O sight': {'O': 9.202595131827176e-05},
#  'O fifth': {'O': 0.0013327205882352942},
#  'O title': {'O': 0.0006897820288788742},
#  'O year': {'O': 0.009300205151584227},
#  'O when': {'O': 0.007490294587805435},
#  'O hurried': {'O': 9.202595131827176e-05},
#  'O only': {'O': 0.004580642206037286},
#  'O 40': {'O': 0.0012409228789410792},
#  'O minutes': {'O': 0.002799192364170338},
#  'O final': {'O': 0.002661893616044793},
#  'O richest': {'O': 0.0001840349666436623},
#  'O squash': {'O': 9.202595131827176e-05},
#  'O tournament': {'O': 0.001608012496554259},
#  'O outside': {'O': 0.0009194979541170521},
#  'B-MISC Open': {'I-MISC': 0.0017914561322921452},
#  'I-MISC ,': {'O': 0.0016538797261910231},
#  'O 105,000': {'O': 0.00013803257568786233},
#  'O Mahindra': {'B-MISC': 9.202171712524156e-05,
#   'B-ORG': 9.202171712524156e-05},
#  'B-ORG International': {'I-ORG': 0.0001840349666436623},
#  'pi Halftime': {'O': 0.0012409228789410792},
#  'pi Attendance': {'O': 0.0019748323688803158},
#  'O 8,000': {'O': 0.00045996044340186745},
#  'pi INDICATORS': {'O': 0.0001840349666436623},
#  'O Hungary': {'B-LOC': 0.0003220167448707333},
#  'B-LOC -': {'O': 0.0015162653923911046},
#  'O updated': {'O': 0.00023003312476996689},
#  'O Aug': {'O': 0.000965428466347922},
#  'O 22': {'O': 0.0020664952240999263},
#  'pi 22=': {'O': 0.00013803257568786233},
#  'O Anita': {'B-PER': 0.0001840349666436623},
#  'B-PER Wachter': {'I-PER': 0.0001840349666436623},
#  'O Austria': {'B-LOC': 0.002158042150695624, 'B-PER': 9.183158088066487e-05},
#  'O 1:19.21': {'O': 0.00013803257568786233},
#  'O Morris': {'B-PER': 0.0002760270506509638},
#  'B-PER has': {'O': 0.0015162653923911046},
#  'O trying': {'O': 0.0012868238430074912},
#  'B-PER a': {'O': 0.0002760270506509638},
#  'O Republican': {'B-MISC': 0.000873442743529628,
#   'B-ORG': 0.00018388268284834277},
#  'O maybe': {'O': 0.0002760270506509638},
#  'O revert': {'O': 9.202595131827176e-05},
#  ...}

# %%
a={}
a[str([2,1])]=3
a
# Out:
# {'[2, 1]': 3}

# %%
#Compute State Transition Probabilities
#use pre-processed list so that it includes pi

#Training Set
pp_sentences_train=preProcessIOBTagList(sentences_train)
bigram_model_prob_train = get_kn_abs_disc_prob_bigram(pp_sentences_train)
trans_prob_train = get_graph_states_prob(bigram_model_prob_train)

#Entire Training Set
pp_sentences_tr=preProcessIOBTagList(sentences_tr)
bigram_model_prob_tr = get_kn_abs_disc_prob_bigram(pp_sentences_tr)
trans_prob_tr = get_graph_states_prob(bigram_model_prob_tr)

#Compute Lexical Word Gen Prob
#Training Set
flattened_sentences_train = flatten_nested_lists(sentences_train)
ner_tags_sentences_train = flatten_nested_lists(ner_tags_train)
word_gen_prob_train = get_word_gen_prob(flattened_sentences_train,ner_tags_sentences_train)

#Entire Training Set
flattened_sentences_tr = flatten_nested_lists(sentences_tr)
ner_tags_sentences_tr = flatten_nested_lists(ner_tags_tr)
word_gen_prob_tr = get_word_gen_prob(flattened_sentences_tr,ner_tags_sentences_tr)

#Compute next_tag_prob for MEMM
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-366-75c2eb1ce443> in <module>()
#      16 flattened_sentences_train = flatten_nested_lists(sentences_train)
#      17 ner_tags_sentences_train = flatten_nested_lists(ner_tags_train)
# ---> 18 word_gen_prob_train = get_word_gen_prob(flattened_sentences_train,ner_tags_sentences_train)
#      19
#      20 #Entire Training Set
#
# <ipython-input-204-f6e2d8143668> in get_word_gen_prob(data_list, ner_tags, k, graph_states)
#      40         word=phrase.split()[1]
#      41
# ---> 42         result[tag][word]= (state_word_count[word]+k)/(states_count[tag] + k*V)
#      43
#      44     #to fetch in required format
#
# KeyError: 'Returns'

# %% [markdown]
# # Viterbi Algorithm - HMM

# %%
# Input format
# line =[ , , ]
# graph -> Represent as adjacency list { t1: { t2: score}} , also add tag for pi -> unigram prob of first word in sentence
# word_tag_dict = { t1: { w1:prob, w2: prob }} 
#Unseen and unknown tags can be handled before 
#Unseen words can be handled but unknown words need to be handled here
def viterbi_hmm(line,graph, word_tag_dict):
    T = len(line)
    states = [tag for tag in graph.keys() if tag!=GRAPH_START_STATE] 
    N = len(states)
    viterbi = np.zeros((N,T))
    bp = np.zeros((N,T))
    
    for i in range(N):
        if line[0] in word_tag_dict[states[i]].keys():
            viterbi[i][0] = graph[GRAPH_START_STATE][states[i]] * word_tag_dict[states[i]][line[0]]
        else:
            viterbi[i][0] = graph[GRAPH_START_STATE][states[i]] * word_tag_dict[UNKNOWN_WORD]
        bp[i][0] = 0
    
    for t in range(1,T):
        for s in range(N):
            prob_to_state=np.zeros(N)
            for j in range(N):
                if line[t] in word_tag_dict[states[s]].keys():
                    prob_to_state[j] = viterbi[j][t-1] * graph[states[j]][states[s]] * word_tag_dict[states[s]][line[t]]
                else:
                    prob_to_state[j] = viterbi[j][t-1] * graph[states[j]][states[s]] * word_tag_dict[UNKNOWN_WORD]
                        
            viterbi[s][t] = np.max(prob_to_state)
            bp[s][t] = np.argmax(prob_to_state).astype(int)    
    
    path = []
    tag_index = np.argmax(viterbi,axis=0)[T-1].astype(int)
    #print(viterbi)
    #print(bp)
    #print(tag_index)
    
    for i in reversed(range(T)):    
        path.append(states[tag_index])
        tag_index = (bp[tag_index][i]).astype(int) 
        
    path = path[::-1]
    
    return path

# %% [markdown]
# # Viterbi algorithm - MEMM

# %%
# Input format
# line =[ , , ]
# new_tag_prob  -> { [tprev,word1] : {tcur: } }
def viterbi_memm(line,graph, word_tag_dict):
    T = len(line)
    states = [tag for tag in graph.keys() if tag!=GRAPH_START_STATE] 
    N = len(states)
    viterbi = np.zeros((N,T))
    bp = np.zeros((N,T))
    
    for i in range(N):
        
        viterbi[i][0] = new_tag_prob[[GRAPH_START_STATE,line[0]]][states[i]] 
        bp[i][0] = 0
    
    for t in range(1,T):
        for s in range(N):
            prob_to_state=np.zeros(N)
            for j in range(N):
                prob_to_state[j] = viterbi[j][t-1] * new_tag_prob[[states[j],line[t]]][states[s]] 
                        
            viterbi[s][t] = np.max(prob_to_state)
            bp[s][t] = np.argmax(prob_to_state).astype(int)     
    
    path = []
    tag_index = np.argmax(viterbi,axis=0)[T-1].astype(int) 
    
    for i in reversed(range(T)):     
        path.append(states[tag_index])
        tag_index = bp[tag_index][i].astype(int) 
        print(tag_index)
        
    path = path[::-1]
    
    return path

# %% [markdown]
# # MEMM 2

# %%
# Input format
# line =[ , , ]
# new_tag_prob  -> { 'tprev word1' : {tcur: } }
def viterbi_memm_2(line,graph, new_tag_prob,k):
    T = len(line)
    states = [tag for tag in graph.keys() if tag!=GRAPH_START_STATE] 
    N = len(states)
    viterbi = np.zeros((N,T))
    bp = np.zeros((N,T))
    
    for i in range(N):
        key=GRAPH_START_STATE+SPACE+line[0]
        if key in new_tag_prob.keys():
            if states[i] in new_tag_prob[key].keys():
                viterbi[i][0] = new_tag_prob[key][states[i]]
            else:
                viterbi[i][0] = k/new_tag_prob[key]['sm_bigram_count']
            
        else:
            viterbi[i][0] = new_tag_prob[UNKNOWN_WORD]
        bp[i][0] = 0
    
    for t in range(1,T):
        for s in range(N):
            prob_to_state=np.zeros(N)
            for j in range(N):
                key=states[j]+SPACE+line[t]
                if key in new_tag_prob.keys():
                    if states[s] in new_tag_prob[key].keys():
                        prob_to_state[j] = viterbi[j][t-1] * new_tag_prob[key][states[s]] 
                    else:
                        prob_to_state[j] = k / new_tag_prob[key]['sm_bigram_count'] 
                else:
                    prob_to_state[j] = viterbi[j][t-1] * new_tag_prob[UNKNOWN_WORD]
                        
            viterbi[s][t] = np.max(prob_to_state)
            bp[s][t] = np.argmax(prob_to_state).astype(int)     
    
    path = []
    tag_index = np.argmax(viterbi,axis=0)[T-1].astype(int) 
    
    for i in reversed(range(T)):     
        path.append(states[tag_index])
        tag_index = bp[tag_index][i].astype(int) 
        #print(tag_index)
        
    path = path[::-1]
    
    return path

# %%
k=0
V=len(set(flatten_nested_lists(sentences_train)))

pp_sentences_train=preProcessIOBTagList(sentences_train)
pp_ner_tags_train=preProcessIOBTagList(ner_tags_train)
res =get_next_tag_prob(pp_sentences_train,pp_ner_tags_train,k,V)
line=sentences_val[0]
corr=ner_tags_val[0]
print(line)
print(corr)
pred=viterbi_memm_2(line,trans_prob_train,res,k)
evaluate_model_span(pred,corr)
# Out:
# ['Summaries', 'of', 'French', 'first', 'division']
# ['O', 'O', 'B-MISC', 'O', 'O']
# 8
# 3
# 8
# 8
# 0
# (1.0, 1.0, 1.0)

# %% [markdown]
# # Evaluation

# %%
def evaluate_model_span(predicted_seq, correct_seq):
    T = len(predicted_seq)
    
    num_spans_pred = ['B-' in x for x in predicted_seq].count(True)
    num_spans_ans = ['B-' in x for x in correct_seq].count(True)
    
    correct_pred=0
    
    for i in range(len(correct_seq)):
        
        if 'B-' in correct_seq[i]:
            if correct_seq[i]==predicted_seq[i]:
                flag=1;
                tag_type = correct_seq[i][2:]
                j=i+1
                while( j<T and (correct_seq[j] == 'I-'+tag_type or predicted_seq[j] == 'I-'+tag_type)):
                    #print("here")
                    if (correct_seq[j]!=predicted_seq[j]):
                        flag=0;
                    
                    j=j+1             
                
                if(flag==1):
                    correct_pred+=1;
                               
                i=j-1
                
                
    precision = correct_pred/num_spans_pred;
    recall = correct_pred/num_spans_ans;
    
    f_score = (2*precision*recall)/(precision+recall)
                
    return precision, recall, f_score

# %%
a=[1,2,3]

# %%
a=['B-ORG', 'O', 'B-ORG', 'O','B-MISC', 'I-MISC']
['B-' in x for x in a].count(True)
# Out:
# 3

# %%
corr=['O','B-PER','I-PER','B-LOC','O','O','B-MISC','B-MISC', 'I-MISC','I-MISC']
pred=['B-PER','B-PER','I-PER','B-LOC','O','O','O','B-LOC', 'I-MISC','I-LOC']

# %%
flatten_nested_lists([corr,pred])
# Out:
# ['O',
#  'B-PER',
#  'I-PER',
#  'B-LOC',
#  'O',
#  'O',
#  'B-MISC',
#  'B-MISC',
#  'I-MISC',
#  'I-MISC',
#  'B-PER',
#  'B-PER',
#  'I-PER',
#  'B-LOC',
#  'O',
#  'O',
#  'O',
#  'B-LOC',
#  'I-MISC',
#  'I-LOC']

# %%
evaluate_model_span(pred,corr)
# Out:
# (0.5, 0.5, 0.5)

# %%
a[0][2:]
# Out:
# 'ORG'

# %% [markdown]
# # Analysis - HMM

# %%
#Validation Set
#Use train set here instead of tr set 
pred=[]
for line in sentences_val:
    ans = viterbi_hmm(line,trans_prob_train, word_gen_prob_train)
    pred.append(ans)

# %%
pred
# Out:
# [['O', 'I-ORG', 'B-MISC', 'O', 'I-MISC'],
#  ['O', 'B-PER', 'B-PER', 'O', 'B-LOC', 'O', 'B-PER'],
#  ['O',
#   'O',
#   'B-ORG',
#   'I-ORG',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'O'],
#  ['B-PER', 'B-PER', 'O', 'B-PER', 'I-LOC', 'B-PER', 'O', 'B-PER'],
#  ['B-LOC', 'B-PER', 'O', 'B-ORG', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'B-PER', 'B-PER', 'B-PER', 'B-PER'],
#  ['B-PER', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER'],
#  ['O', 'O', 'B-LOC', 'B-PER', 'B-PER', 'B-PER', 'O', 'O', 'O', 'B-PER', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O', 'O'],
#  ['B-PER', 'B-PER', 'O', 'B-ORG', 'I-ORG', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O'],
#  ['I-MISC', 'O', 'O', 'O'],
#  ['B-LOC',
#   'I-LOC',
#   'I-ORG',
#   'I-ORG',
#   'I-PER',
#   'B-PER',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'B-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-MISC',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'B-MISC',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'B-MISC',
#   'I-ORG',
#   'I-ORG',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['O',
#   'B-LOC',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['B-LOC', 'O'],
#  ['O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['O',
#   'B-MISC',
#   'I-ORG',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O'],
#  ['I-MISC', 'O', 'O', 'O', 'O'],
#  ['O', 'B-PER', 'B-PER', 'O', 'B-LOC', 'O', 'O', 'O', 'B-PER', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-LOC', 'B-PER', 'B-PER'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'B-PER'],
#  ['O', 'B-PER', 'B-PER', 'O', 'B-LOC', 'O', 'B-LOC', 'B-PER'],
#  ['B-LOC',
#   'I-LOC',
#   'O',
#   'B-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'B-PER', 'B-PER', 'O', 'B-LOC', 'O', 'B-PER'],
#  ['B-ORG', 'I-ORG', 'O', 'O', 'B-PER', 'O'],
#  ['O', 'B-LOC', 'O', 'O', 'O', 'B-PER', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'B-PER', 'O', 'B-PER', 'O', 'B-PER', 'O', 'B-PER'],
#  ['O',
#   'B-PER',
#   'B-PER',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['B-LOC',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'B-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'O'],
#  ['B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-ORG', 'I-MISC'],
#  ['B-PER',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-ORG', 'B-PER', 'O', 'B-ORG', 'O', 'I-ORG', 'O', 'O'],
#  ['O', 'B-ORG', 'B-LOC', 'I-ORG', 'O', 'O', 'O', 'O'],
#  ['B-ORG',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['B-PER', 'B-PER', 'O', 'B-LOC', 'O', 'O', 'O', 'O'],
#  ['O', 'B-PER', 'B-PER', 'O', 'B-LOC', 'O', 'B-PER', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'B-PER',
#   'I-ORG',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['B-ORG', 'I-ORG', 'O', 'B-ORG', 'O'],
#  ['B-ORG', 'B-PER', 'I-ORG', 'O', 'O'],
#  ['O', 'B-PER', 'B-PER', 'O', 'B-LOC', 'O', 'B-PER'],
#  ['I-MISC',
#   'B-PER',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['B-PER', 'O', 'B-LOC', 'B-ORG', 'O'],
#  ['B-LOC',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'B-MISC',
#   'I-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'I-MISC',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['O',
#   'O',
#   'I-ORG',
#   'O',
#   'B-ORG',
#   'O',
#   'I-MISC',
#   'I-ORG',
#   'O',
#   'B-PER',
#   'O',
#   'B-PER',
#   'B-PER',
#   'O',
#   'O',
#   'B-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['I-ORG', 'O'],
#  ['O', 'O', 'O', 'B-PER', 'B-PER', 'O', 'O', 'O'],
#  ['O', 'B-PER', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O', 'O', 'B-PER', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'I-ORG',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['B-LOC',
#   'B-ORG',
#   'O',
#   'O',
#   'B-ORG',
#   'I-ORG',
#   'O',
#   'O',
#   'B-ORG',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'O', 'O'],
#  ['O', 'I-ORG', 'B-MISC', 'O', 'I-MISC'],
#  ['B-ORG',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'B-PER',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O'],
#  ['O', 'B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'O'],
#  ['B-ORG',
#   'O',
#   'I-ORG',
#   'B-MISC',
#   'I-MISC',
#   'I-MISC',
#   'I-MISC',
#   'B-PER',
#   'B-PER',
#   'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-MISC',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['O', 'B-PER', 'B-PER', 'O', 'B-LOC', 'O', 'B-PER'],
#  ['B-LOC', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'B-MISC', 'O', 'O', 'O', 'B-MISC', 'O', 'O', 'B-MISC', 'O', 'O'],
#  ['I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['I-ORG',
#   'B-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['B-PER',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'B-PER',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'B-LOC',
#   'B-PER',
#   'B-PER'],
#  ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-LOC',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['O', 'O', 'B-PER', 'O', 'B-PER'],
#  ['O', 'O', 'O', 'I-ORG', 'O', 'B-MISC', 'I-MISC', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-MISC',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['B-LOC', 'O', 'O', 'O', 'O', 'B-PER', 'B-PER', 'B-PER', 'O'],
#  ['I-PER',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'B-PER',
#   'O',
#   'B-PER',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['B-LOC', 'O', 'B-LOC', 'O'],
#  ['B-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['B-ORG',
#   'I-ORG',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'B-ORG',
#   'I-ORG',
#   'I-ORG',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-PER', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'I-ORG', 'B-PER', 'O', 'O', 'O'],
#  ['I-ORG', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'B-LOC',
#   'I-ORG',
#   'I-ORG',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'B-ORG',
#   'O',
#   'B-PER',
#   'B-PER',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'I-ORG',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['O', 'O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'B-PER',
#   'O'],
#  ['I-MISC', 'B-PER', 'O', 'O', 'O', 'O'],
#  ['B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-ORG', 'O', 'B-ORG', 'O'],
#  ['O', 'O', 'B-MISC', 'I-MISC', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'B-PER',
#   'O',
#   'B-PER',
#   'B-PER',
#   'O',
#   'I-PER',
#   'B-PER',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['B-MISC',
#   'B-ORG',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'I-ORG',
#   'B-MISC',
#   'B-PER',
#   'I-PER',
#   'O'],
#  ['I-MISC',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER'],
#  ['B-LOC', 'O'],
#  ['B-LOC', 'O', 'O', 'B-PER', 'O'],
#  ['B-PER',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'B-MISC',
#   'I-MISC',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['B-PER',
#   'I-ORG',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'I-MISC',
#   'O',
#   'O',
#   'O'],
#  ['B-ORG',
#   'O',
#   'B-ORG',
#   'I-ORG',
#   'I-ORG',
#   'B-LOC',
#   'O',
#   'B-ORG',
#   'I-ORG',
#   'B-LOC',
#   'O',
#   'O',
#   'B-ORG',
#   'I-ORG',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['B-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-PER',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-ORG',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'B-PER',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['B-PER', 'B-PER', 'O', 'B-PER'],
#  ['B-LOC', 'B-PER'],
#  ['O', 'O', 'B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['I-MISC', 'O', 'O', 'O'],
#  ['O',
#   'B-MISC',
#   'I-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['B-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'B-PER'],
#  ['B-ORG', 'I-MISC'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['O', 'I-ORG', 'I-ORG', 'B-PER', 'O', 'B-PER', 'B-PER'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['B-PER',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['O', 'B-PER', 'B-PER', 'O', 'B-LOC', 'O', 'O', 'O', 'O'],
#  ['B-MISC', 'I-MISC'],
#  ['O', 'O', 'O', 'B-PER', 'O', 'B-PER', 'O', 'O', 'O'],
#  ['B-MISC', 'I-MISC', 'O', 'O', 'B-ORG', 'O', 'B-ORG', 'O'],
#  ['O', 'B-LOC', 'O'],
#  ['O', 'B-PER', 'B-PER', 'O', 'B-LOC', 'O', 'B-PER'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'B-PER',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['B-PER', 'I-PER', 'O', 'I-PER', 'O', 'I-PER', 'O'],
#  ['B-ORG', 'I-ORG', 'O', 'O', 'B-PER', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-ORG', 'I-ORG', 'O', 'O'],
#  ['B-ORG', 'O', 'B-LOC', 'I-LOC', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O'],
#  ['O', 'B-PER', 'B-PER', 'O', 'B-LOC', 'O', 'B-PER'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'I-ORG',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['O',
#   'I-MISC',
#   'I-ORG',
#   'B-PER',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-MISC',
#   'I-MISC',
#   'I-MISC',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'B-PER', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'O'],
#  ['O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['B-ORG', 'B-ORG', 'B-PER', 'O', 'I-ORG', 'B-PER', 'O', 'B-PER', 'O'],
#  ['O', 'O', 'B-PER', 'O', 'B-MISC', 'O', 'O', 'O', 'O'],
#  ['B-ORG',
#   'I-MISC',
#   'B-LOC',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['B-PER', 'I-PER', 'O'],
#  ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-MISC', 'O', 'B-MISC', 'O', 'O'],
#  ['O', 'B-LOC', 'O', 'B-PER', 'B-PER'],
#  ['B-ORG', 'O', 'B-ORG'],
#  ['O', 'B-LOC', 'O', 'B-PER', 'O', 'O', 'O', 'O'],
#  ['B-MISC', 'I-MISC', 'O', 'O', 'B-LOC', 'I-ORG', 'O', 'B-ORG', 'B-LOC', 'O'],
#  ['O', 'O'],
#  ['O', 'B-PER', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'B-ORG', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-MISC',
#   'I-ORG',
#   'I-ORG',
#   'B-PER',
#   'O',
#   'B-ORG',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['B-PER', 'B-PER', 'O', 'B-PER', 'I-PER', 'O'],
#  ['B-LOC', 'I-LOC', 'O'],
#  ['B-PER', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'B-PER', 'B-PER', 'O', 'B-LOC', 'O', 'B-PER'],
#  ['B-PER', 'B-PER', 'O', 'O', 'B-LOC'],
#  ['B-ORG', 'O'],
#  ['B-PER',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['I-ORG',
#   'O',
#   'I-ORG',
#   'I-ORG',
#   'B-PER',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['B-LOC', 'I-LOC', 'O', 'B-ORG', 'I-ORG'],
#  ['I-MISC', 'O', 'O'],
#  ['B-MISC',
#   'I-LOC',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-LOC', 'O'],
#  ['O', 'O', 'B-MISC', 'I-MISC', 'O', 'O'],
#  ['B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-LOC', 'O'],
#  ['B-ORG', 'O', 'O', 'O'],
#  ['B-PER', 'B-PER', 'O', 'B-PER', 'I-PER', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['B-LOC',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'O'],
#  ['I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'B-MISC',
#   'I-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['B-PER', 'O', 'B-LOC', 'O'],
#  ['O', 'I-PER', 'O', 'I-PER', 'O', 'O'],
#  ['O',
#   'O',
#   'B-PER',
#   'O',
#   'B-PER',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['B-ORG', 'O', 'B-ORG', 'I-ORG', 'O'],
#  ['O',
#   'O',
#   'I-ORG',
#   'I-MISC',
#   'O',
#   'B-ORG',
#   'O',
#   'I-MISC',
#   'B-PER',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['B-ORG', 'O', 'B-ORG', 'O', 'B-PER', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['B-PER',
#   'B-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'B-ORG', 'O', 'B-ORG', 'I-MISC', 'O', 'B-ORG', 'O', 'B-ORG'],
#  ['B-PER', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'B-PER', 'B-PER', 'O', 'B-PER'],
#  ['I-MISC'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-PER', 'O'],
#  ['O', 'I-ORG', 'O', 'B-MISC', 'O', 'I-MISC', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'I-ORG', 'O', 'O', 'I-ORG', 'O', 'O', 'O', 'O'],
#  ['O',
#   'B-ORG',
#   'I-ORG',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['O', 'O', 'B-MISC', 'O', 'I-MISC', 'O', 'O'],
#  ['O', 'I-ORG', 'B-MISC', 'I-MISC'],
#  ['O', 'O', 'O', 'B-PER', 'O', 'O', 'O', 'O', 'O', 'B-PER'],
#  ['B-LOC', 'O'],
#  ['B-PER', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'B-PER', 'O'],
#  ['B-LOC', 'O', 'B-LOC', 'O'],
#  ['B-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['B-ORG', 'O', 'B-ORG'],
#  ['O', 'B-ORG', 'I-ORG', 'B-PER'],
#  ['O', 'B-PER', 'B-ORG', 'B-PER', 'O', 'B-LOC', 'O', 'O', 'O', 'B-PER', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O'],
#  ['B-PER',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-ORG',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['B-ORG',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'I-MISC', 'B-PER'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['O',
#   'B-MISC',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'O'],
#  ['B-ORG', 'O', 'O', 'O', 'B-PER', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'B-LOC',
#   'I-ORG',
#   'B-PER',
#   'I-ORG',
#   'B-PER',
#   'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'B-PER'],
#  ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER'],
#  ['B-ORG', 'O', 'O', 'O', 'B-PER', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'B-ORG', 'I-LOC', 'O'],
#  ['I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'B-LOC',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['B-PER',
#   'B-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'I-PER',
#   'I-ORG',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'B-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['B-PER', 'B-PER'],
#  ['B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['B-ORG',
#   'I-ORG',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['O', 'I-PER', 'I-PER', 'O', 'B-LOC', 'O', 'B-LOC', 'B-PER'],
#  ['O', 'B-PER', 'B-PER', 'O', 'B-LOC', 'O', 'B-PER'],
#  ['O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-MISC', 'O', 'B-PER', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-LOC', 'O'],
#  ['B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['O', 'O', 'O', 'O'],
#  ['B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'B-ORG',
#   'I-ORG',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['B-LOC',
#   'O',
#   'B-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'O'],
#  ['O', 'B-PER', 'B-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O', 'B-PER', 'I-ORG', 'O', 'O'],
#  ['O',
#   'B-PER',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O'],
#  ['O', 'B-LOC', 'I-ORG', 'O', 'O', 'B-PER', 'O', 'B-PER', 'B-PER'],
#  ['I-PER',
#   'O',
#   'O',
#   'I-ORG',
#   'B-PER',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'B-PER',
#   'B-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'B-ORG', 'O', 'O', 'O', 'O'],
#  ['I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O'],
#  ['B-ORG', 'O'],
#  ['I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['O',
#   'I-ORG',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'O'],
#  ['B-LOC', 'O'],
#  ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-LOC', 'B-ORG', 'B-PER', 'O', 'B-PER', 'I-ORG', 'B-PER', 'O'],
#  ['B-LOC', 'I-ORG', 'O', 'B-ORG', 'O'],
#  ['B-PER', 'B-PER', 'O', 'B-LOC', 'O', 'B-PER'],
#  ['O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER'],
#  ['B-PER', 'O', 'I-PER', 'O', 'B-PER', 'O'],
#  ['B-PER', 'I-PER', 'O', 'I-PER', 'O', 'B-PER', 'I-PER', 'O'],
#  ['B-MISC', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'B-PER', 'O'],
#  ['O', 'B-PER', 'I-MISC', 'B-MISC', 'I-MISC', 'O', 'B-PER', 'O', 'O'],
#  ['B-PER', 'B-LOC', 'B-PER'],
#  ['I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'B-PER',
#   'I-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-MISC', 'O', 'O', 'O', 'I-ORG', 'O', 'O', 'O'],
#  ['B-PER',
#   'B-MISC',
#   'B-PER',
#   'I-LOC',
#   'I-ORG',
#   'B-PER',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'O'],
#  ['O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['I-PER', 'O', 'I-PER', 'B-PER', 'B-PER', 'O'],
#  ['B-ORG', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O', 'O'],
#  ['B-PER',
#   'O',
#   'B-ORG',
#   'B-PER',
#   'O',
#   'B-PER',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'B-ORG'],
#  ['O', 'O', 'O', 'B-LOC', 'O', 'O', 'O'],
#  ['I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'B-LOC', 'B-PER', 'B-PER', 'O', 'O', 'O', 'O'],
#  ['B-MISC', 'I-MISC'],
#  ['O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-PER'],
#  ['I-ORG'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'I-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'B-PER',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['B-PER', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'O', 'O'],
#  ['B-PER', 'B-PER'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'O', 'O', 'O'],
#  ['B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'I-ORG',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O'],
#  ['O', 'O', 'I-MISC', 'O', 'O'],
#  ['B-ORG',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'O',
#   'O',
#   'B-ORG',
#   'I-ORG'],
#  ['B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'I-LOC',
#   'O',
#   'B-PER',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['O', 'B-PER', 'B-PER', 'O', 'B-LOC', 'O', 'B-ORG', 'B-PER'],
#  ['B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-LOC',
#   'B-PER',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'B-PER'],
#  ['B-LOC', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-ORG',
#   'B-MISC',
#   'I-ORG',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O'],
#  ['B-LOC', 'O'],
#  ['B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['B-PER', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'O', 'O', 'O'],
#  ['I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['B-ORG', 'O', 'B-ORG', 'O', 'O', 'O', 'B-MISC', 'O', 'O', 'O'],
#  ['B-LOC'],
#  ['O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['B-ORG',
#   'I-ORG',
#   'B-LOC',
#   'O',
#   'B-LOC',
#   'O',
#   'B-ORG',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'O'],
#  ['I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-MISC',
#   'I-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-ORG',
#   'B-LOC',
#   'I-ORG',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['B-PER',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'B-PER',
#   'B-LOC',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O'],
#  ['O', 'I-PER', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'B-PER'],
#  ['O', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['O', 'O'],
#  ['B-MISC', 'O'],
#  ['B-LOC', 'O'],
#  ['I-ORG', 'O', 'B-PER', 'B-PER', 'B-PER', 'B-PER'],
#  ['O',
#   'B-PER',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'B-MISC', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O'],
#  ['I-ORG', 'O', 'B-ORG', 'I-ORG', 'O', 'I-ORG', 'O', 'I-ORG'],
#  ['O', 'B-PER', 'B-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['B-LOC', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'B-PER', 'O'],
#  ['O',
#   'O',
#   'I-ORG',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'B-PER', 'O'],
#  ['B-PER', 'B-PER'],
#  ['B-MISC', 'O', 'I-MISC', 'O'],
#  ['O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O'],
#  ['O', 'B-ORG', 'I-ORG', 'O', 'B-PER', 'O', 'O', 'O'],
#  ['O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['I-MISC',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'I-MISC',
#   'B-MISC',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['O', 'O', 'B-PER', 'B-PER', 'B-PER', 'B-LOC', 'O', 'O'],
#  ['O', 'O', 'O', 'O'],
#  ['O', 'B-LOC', 'I-LOC', 'O'],
#  ['B-MISC',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['B-LOC', 'O'],
#  ['O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'O',
#   'B-PER',
#   'B-PER',
#   'O',
#   'B-PER',
#   'B-PER',
#   'O',
#   'I-PER',
#   'B-ORG',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-MISC',
#   'I-PER'],
#  ['B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O'],
#  ['I-MISC', 'O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'B-MISC',
#   'B-PER',
#   'O'],
#  ['B-LOC', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['O',
#   'O',
#   'B-PER',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'I-ORG',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['B-LOC', 'O'],
#  ['O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'B-ORG', 'O', 'B-PER'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['B-ORG',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['B-ORG',
#   'O',
#   'B-PER',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['B-ORG',
#   'O',
#   'B-PER',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-ORG', 'O', 'B-ORG', 'O'],
#  ['B-PER'],
#  ['O', 'B-PER', 'B-PER', 'B-PER', 'O', 'B-LOC', 'O', 'B-PER', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['B-ORG', 'O', 'O', 'B-PER', 'O'],
#  ['B-PER', 'B-PER', 'O', 'O', 'O'],
#  ['B-LOC', 'O'],
#  ['B-LOC', 'O'],
#  ['B-LOC',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'B-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O'],
#  ['O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'I-ORG',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['O',
#   'O',
# ...
#  ['B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-PER',
#   'B-PER',
#   'B-PER',
#   'O',
#   'B-PER',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-ORG',
#   'O',
#   'O'],
#  ['B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['O',
#   'O',
#   'I-LOC',
#   'B-LOC',
#   'O',
#   'O',
#   'B-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O'],
#  ['B-PER', 'O', 'B-PER', 'B-PER', 'O'],
#  ['I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O'],
#  ['B-LOC', 'B-LOC', 'O', 'O', 'O', 'B-PER', 'O', 'O'],
#  ['O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['B-LOC', 'O'],
#  ['I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-PER',
#   'B-PER',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['I-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O'],
#  ['B-LOC', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['O', 'O', 'B-PER', 'O', 'O', 'O', 'B-LOC', 'B-ORG', 'I-MISC', 'O', 'O'],
#  ['O', 'B-PER', 'O', 'O', 'B-PER', 'O', 'O', 'I-PER', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'B-PER', 'B-PER', 'O', 'B-LOC', 'O', 'B-PER'],
#  ['B-ORG', 'O', 'O', 'O', 'O'],
#  ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'B-PER', 'O'],
#  ['O', 'O', 'B-LOC', 'I-PER', 'O', 'O', 'B-PER', 'O', 'O', 'O', 'B-LOC', 'O'],
#  ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'I-ORG', 'O'],
#  ['B-PER', 'B-PER', 'O', 'B-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'O'],
#  ['O', 'O'],
#  ['B-LOC', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'O'],
#  ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'B-LOC', 'O'],
#  ['B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O'],
#  ['I-MISC', 'O', 'O', 'O', 'O', 'B-PER', 'O', 'B-PER', 'O'],
#  ['B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'B-PER',
#   'I-LOC',
#   'O',
#   'B-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'B-PER',
#   'I-ORG',
#   'B-LOC',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'B-PER',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['O', 'O'],
#  ['O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-PER',
#   'B-PER',
#   'I-PER',
#   'I-ORG',
#   'B-LOC',
#   'I-LOC',
#   'O',
#   'B-PER',
#   'I-PER',
#   'I-ORG',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'B-LOC',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['O', 'B-LOC', 'I-ORG', 'O', 'O', 'O', 'B-PER'],
#  ['B-LOC', 'O', 'B-PER', 'I-PER', 'O'],
#  ['O', 'B-PER', 'B-PER', 'O', 'B-LOC', 'O', 'B-ORG', 'B-PER'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['O', 'B-PER', 'B-PER', 'B-PER', 'B-PER'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'B-PER', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'B-PER', 'O'],
#  ['O',
#   'B-MISC',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'I-PER',
#   'B-PER',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'B-PER',
#   'B-PER',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['O'],
#  ['B-ORG', 'O', 'O', 'B-PER', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'I-PER',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['O', 'I-PER', 'O', 'O', 'O'],
#  ['B-LOC', 'O'],
#  ['B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'O'],
#  ['O',
#   'O',
#   'B-PER',
#   'I-LOC',
#   'I-PER',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-PER',
#   'O',
#   'O',
#   'B-MISC',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['O', 'B-ORG', 'I-ORG', 'O', 'O'],
#  ['O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'B-MISC',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-LOC', 'O'],
#  ['B-LOC', 'O'],
#  ['O',
#   'B-PER',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'I-ORG',
#   'O',
#   'I-ORG',
#   'O',
#   'B-LOC',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['O', 'O'],
#  ['B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'B-LOC',
#   'I-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['B-PER', 'I-PER', 'O', 'O', 'B-ORG', 'O'],
#  ['B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'B-PER',
#   'I-PER',
#   'I-PER',
#   'O',
#   'B-LOC',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['O',
#   'I-MISC',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['I-MISC', 'O', 'O'],
#  ['B-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'O'],
#  ['O',
#   'I-ORG',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'I-ORG',
#   'O'],
#  ['B-PER', 'B-ORG', 'B-PER'],
#  ['B-LOC', 'I-LOC', 'O', 'O', 'O', 'O'],
#  ['B-PER',
#   'B-MISC',
#   'O',
#   'I-MISC',
#   'O',
#   'B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'I-ORG',
#   'B-PER',
#   'B-ORG',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['I-MISC',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'B-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'B-PER',
#   'B-ORG',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'B-MISC',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['B-ORG', 'I-LOC', 'O', 'B-ORG', 'O'],
#  ['B-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'O'],
#  ['I-PER',
#   'I-LOC',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-ORG', 'I-ORG', 'B-PER', 'O', 'O', 'B-PER', 'O'],
#  ['O', 'B-LOC', 'I-ORG', 'B-PER', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O'],
#  ['B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'B-PER', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'B-LOC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-ORG', 'O', 'B-ORG', 'O'],
#  ['B-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'B-PER',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['O', 'B-PER', 'B-PER', 'O', 'B-LOC', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-LOC',
#   'I-ORG',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['O', 'O', 'O', 'O', 'O', 'I-ORG', 'O'],
#  ['B-PER', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O'],
#  ['B-LOC', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-LOC', 'B-PER', 'B-PER', 'O', 'O', 'O', 'B-PER', 'O', 'B-PER', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-ORG', 'O', 'O', 'B-PER', 'O'],
#  ['O', 'O', 'O'],
#  ['O', 'B-PER', 'B-PER', 'O', 'B-LOC', 'O', 'B-PER'],
#  ['O',
#   'O',
#   'B-PER',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'I-LOC',
#   'I-MISC',
#   'I-MISC',
#   'O',
#   'O'],
#  ['B-LOC',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['O',
#   'B-PER',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-MISC',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'I-MISC',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['O', 'B-PER', 'O', 'O', 'B-PER', 'O', 'O', 'B-PER', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'B-PER',
#   'B-PER',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O',
#   'B-PER',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'O',
#   'O',
#   'O',
#   'I-ORG',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER',
#   'B-PER'],
#  ['B-LOC', 'I-LOC', 'O', 'O', 'O', 'O', 'B-PER'],
#  ['O',
#   'B-LOC',
#   'I-LOC',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'B-PER',
#   'I-PER',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-PER',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O'],
#  ...]

# %%
ner_tags_trial
# Out:
# [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#  ['B-MISC', 'I-MISC'],
#  ['B-ORG', 'O', 'B-ORG', 'O']]

# %%
evaluate_model_span(flatten_nested_lists(pred),flatten_nested_lists(ner_tags_val))
# Out:
# (0.20427750906892383, 0.5923734385272846, 0.3037932003371734)

# %% [markdown]
# # Analysis - MEMM

# %%
k=0
V=len(set(flatten_nested_lists(sentences_train)))
pp_sentences_train=preProcessIOBTagList(sentences_train)
pp_ner_tags_train=preProcessIOBTagList(ner_tags_train)

res =get_next_tag_prob(pp_sentences_train,pp_ner_tags_train,k,V)
pred=[]
for line in sentences_val:
    ans = viterbi_memm_2(line,trans_prob_train,res, k)
    pred.append(ans)
evaluate_model_span(flatten_nested_lists(pred),flatten_nested_lists(ner_tags_val))
# Out:
# (0.5048686928297433, 0.749945211483673, 0.6034741204479324)

# %% [markdown]
# # Word Embeddings

# %%
from gensim.models import Word2Vec
from sklearn.decomposition import PCA
from matplotlib import pyplot
from gensim.models import KeyedVectors
from gensim.scripts.glove2word2vec import glove2word2vec

# %%
glove_input_file = 'glove.840B.300d.txt'
word2vec_output_file = 'glove.840B.300d.word2vec.txt'
glove2word2vec(glove_input_file, word2vec_output_file)
model = KeyedVectors.load_word2vec_format(word2vec_output_file, binary=False)

# %%
#Read and vectorize Glove 

def loadGloveModel(gloveFile):
    print("Loading File!")
    f = open(gloveFile,'r')
    model = {}
    i=0;
    for line in f:
        splitLine = line.replace("\n","").split(" ")
        word = splitLine[0]
        embedding = np.array([float(val) for val in splitLine[1:]])
        model[word.lower()] = embedding
    print("File Loaded!")
    return model

gloveFile='glove.840B.300d.txt'

glove_model_vectors = loadGloveModel(gloveFile)
# Out:
# Loading File!
# File Loaded!

# %%
len(glove_model_vectors.keys())
# Out:
# 1702926

# %%
#print(training_data_obama_we)

def vectorize_tokens(data_list):
    #300 is dim for glove
    vec=np.zeros(300)
    
    glove_keys = glove_model_vectors.keys()
    
    for token in data_list:
        if token in glove_keys:
            vec+=glove_model_vectors[token]
            
    vec=vec/len(data_list)
    return vec

# %%
vectorize_tokens(['american'])
# Out:
# array([ 0.2539   , -0.36895  ,  0.26033  , -0.10035  , -0.58879  ,
#         0.44728  ,  0.052015 ,  0.78105  , -0.66301  , -1.1887   ,
#        -0.066125 ,  0.86127  , -0.39702  , -0.18537  ,  0.43213  ,
#        -0.14023  , -0.046757 , -1.6801   ,  0.34622  ,  0.79814  ,
#         0.15617  , -0.3673   , -0.22443  ,  0.19137  , -0.28632  ,
#        -0.5484   , -0.077039 , -0.24923  ,  0.36135  ,  0.61197  ,
#        -0.44122  ,  0.16953  ,  0.63045  , -0.084609 , -0.21828  ,
#         0.25694  , -0.23095  , -0.094954 ,  0.16437  ,  0.54833  ,
#         0.5678   ,  0.74866  ,  0.088466 ,  0.38904  ,  0.14308  ,
#        -0.34348  ,  0.55417  , -0.38818  ,  0.081317 , -0.015508 ,
#        -0.65818  , -0.3079   , -0.2125   ,  0.16286  , -0.42047  ,
#         0.013507 ,  0.017612 , -0.15186  , -0.23968  , -0.36223  ,
#         0.032989 , -0.15466  , -0.58381  , -0.15278  ,  0.1111   ,
#        -0.4149   ,  0.33809  , -0.0098793,  0.45988  , -0.44008  ,
#         0.083382 , -0.33664  , -0.2418   ,  0.42795  ,  0.083207 ,
#        -0.50134  , -0.066104 ,  0.079595 , -0.045596 ,  0.29596  ,
#         0.58045  ,  0.24806  ,  0.75182  ,  0.24188  , -0.27378  ,
#        -0.2127   , -0.64467  , -0.28609  , -0.079626 , -0.65421  ,
#        -0.61154  , -0.16202  ,  0.50452  , -0.019134 ,  0.26384  ,
#        -0.36092  , -0.1276   ,  0.073689 ,  0.092144 , -0.42502  ,
#         0.35749  ,  0.30923  ,  0.20541  , -0.4228   ,  0.48403  ,
#        -0.75583  , -0.27148  , -0.27464  , -0.10065  , -0.72594  ,
#         0.14882  ,  0.36083  , -0.64732  , -0.69853  ,  0.37298  ,
#         0.16199  , -0.11003  , -0.43836  ,  0.22681  , -0.68809  ,
#         0.052099 ,  0.019962 , -0.26442  ,  0.29865  ,  0.47341  ,
#        -0.43294  ,  0.26925  ,  0.39938  , -0.1479   , -0.64109  ,
#         0.11972  , -0.76764  , -0.14126  ,  0.55227  ,  0.15177  ,
#        -0.9081   , -0.068918 , -0.064548 ,  0.065622 , -0.13818  ,
#         0.12506  , -0.34247  , -0.3098   ,  0.19056  ,  0.10292  ,
#         0.067908 , -0.42636  ,  0.29092  ,  0.26932  , -0.037311 ,
#        -0.1648   ,  0.10121  , -0.1241   ,  0.17331  ,  0.35836  ,
#        -0.017868 ,  0.7288   , -0.21041  ,  0.04406  ,  0.33282  ,
#        -0.22493  , -0.085854 ,  0.17202  ,  0.31154  ,  0.27419  ,
#         0.20153  ,  0.7618   ,  0.48337  ,  0.026167 , -0.2364   ,
#        -0.10406  ,  0.13996  ,  0.099298 ,  0.07617  , -0.13454  ,
#         0.090887 , -0.005659 ,  0.16896  , -0.95147  , -0.0064111,
#        -0.11043  ,  0.38716  , -0.44697  , -0.22221  ,  0.037497 ,
#         0.61631  , -0.18707  , -0.48259  , -0.001729 ,  0.52131  ,
#         0.041255 , -0.28493  , -0.24125  , -0.12481  ,  0.41948  ,
#         0.24696  , -0.052326 ,  0.14265  ,  0.38478  , -0.23065  ,
#         0.054712 ,  0.87403  ,  0.51925  , -0.37365  ,  0.11988  ,
#         0.40232  ,  0.52657  ,  0.2749   ,  0.14322  ,  0.62847  ,
#        -0.45157  ,  0.0053963, -0.10834  ,  0.4313   , -0.54135  ,
#        -0.14621  , -0.067238 , -0.2      ,  0.17879  , -0.25712  ,
#        -0.27306  ,  0.37088  ,  0.34484  , -0.36948  , -0.20149  ,
#         0.10794  , -0.68326  , -0.13061  ,  0.25312  , -0.021435 ,
#        -0.15702  , -0.42264  ,  0.26186  ,  0.38954  ,  0.28287  ,
#        -0.31224  ,  0.47715  , -0.20814  ,  0.23867  ,  0.67606  ,
#        -0.21594  ,  0.37564  ,  0.14391  , -0.11203  ,  0.18474  ,
#        -0.12188  ,  0.25011  ,  0.478    ,  0.063868 , -0.013945 ,
#         0.059645 ,  0.016364 , -0.52036  , -0.22064  ,  0.39163  ,
#        -0.19253  ,  0.062184 ,  0.52222  , -0.58462  ,  0.18147  ,
#        -0.25247  , -0.14507  , -0.34278  ,  0.27421  ,  0.35529  ,
#         0.54145  , -0.085963 , -0.027982 , -0.43396  ,  0.97166  ,
#        -0.22785  ,  0.011739 ,  0.23587  ,  0.10637  ,  0.40011  ,
#        -0.14587  ,  0.13047  , -0.04403  ,  0.24998  , -0.29362  ,
#        -0.79528  , -0.025668 , -0.16668  , -0.011365 ,  0.017655 ,
#         0.19617  , -0.54194  , -0.042933 ,  0.33424  , -0.43492  ,
#         0.18876  , -0.13516  , -0.40217  , -0.40962  , -0.078349 ,
#         0.21661  , -0.10762  , -0.023671 , -0.91479  ,  0.26854  ])

# %%
def is_Number(string):
    try:
        float(string)
        return 1
    except:
        return 0

# %%
#trial
pos_tags_univ = list(set(flatten_nested_lists(pos_tags_tr)+flatten_nested_lists(pos_tags_te)))
len(pos_tags_univ)
print(pos_tags_univ)
# Out:
# ['VB', 'JJ', ')', 'LS', 'FW', "''", 'WP$', 'NN|SYM', 'WDT', 'NNPS', 'EX', 'CC', 'TO', 'VBZ', ',', 'RB', 'UH', 'WRB', 'VBD', 'MD', 'PDT', 'WP', 'PRP$', 'POS', 'VBN', '.', 'NNP', 'CD', 'JJR', '$', 'VBG', 'RBR', 'DT', 'JJS', 'RBS', '(', 'NNS', ':', 'NN', 'IN', 'SYM', '"', 'PRP', 'RP', 'VBP']

# %%
def feature_extractor(flt_sentences, pos_tags_data):
    N=len(flt_sentences)
    d=303
    feat=np.zeros((N,d))
    label=np.zeros(N)
    words=[]
    nouns=['NN','NNS','NNP','NNPS']
    #print(pos_tags_univ)
    glove_keys = glove_model_vectors.keys()
    for i,word in enumerate(flt_sentences):
        #Probability as continuous feature -- add later
        #print(word)
        #isCapitalized
        feat[i][0]=int(word[0].isupper())
        #isNumber
        feat[i][1]=is_Number(word)
        #is Noun
        if pos_tags_data[i] in nouns:
            feat[i][2]=1
        else:
            feat[i][2]=0
        #POS Tag

        #Word Embedding
        #fetch for lower case
        word_lower = word.lower()
        if word_lower in glove_keys:
            feat[i][3:303]=glove_model_vectors[word_lower]
        else:
            feat[i][3:303]=np.zeros(300)
            
        label[i]=pos_tags_univ.index(pos_tags_data[i])
        words.append(word)
        
    return feat,label,words
        

sample=['I','love','California','1']
pos_tags_data=['JJ','VB','NN','NNP']
feature_extractor(sample,pos_tags_data)
# Out:
# (array([[ 1.      ,  0.      ,  0.      , ...,  0.16495 ,  0.18757 ,
#           0.53874 ],
#         [ 0.      ,  0.      ,  0.      , ...,  0.39089 , -0.16994 ,
#           0.092135],
#         [ 1.      ,  0.      ,  1.      , ..., -0.049514, -0.25006 ,
#           0.40112 ],
#         [ 0.      ,  1.      ,  1.      , ..., -0.61465 ,  0.1773  ,
#           0.1659  ]]),
#  array([ 1.,  0., 38., 26.]),
#  ['I', 'love', 'California', '1'])

# %%
flt_sen = flatten_nested_lists(sentences_train)
flt_pos = flatten_nested_lists(pos_tags_train)
fTr =  feature_extractor(flt_sen,flt_pos)

# %%
print(flt_sen[0])
print(flt_pos[0])
print(len(fTr[0][:]))
# Out:
# Returns
# NNS
# 303

# %%
# Out:
# {'pi O': 0.3333333333333333, 'O O': 0.75, 'O pi': 0.06944444444444445, 'pi B-MISC': 0.2222222222222222, 'B-MISC I-MISC': 0.5555555555555556, 'I-MISC pi': 0.6111111111111112, 'pi B-ORG': 0.2777777777777778, 'B-ORG O': 0.75, 'O B-ORG': 0.06944444444444445, '<unk>': 1.4210526315789474e-07}
# {'B-LOC': {'B-LOC': 1.4210526315789474e-07,
#   'B-MISC': 1.4210526315789474e-07,
#   'B-ORG': 1.4210526315789474e-07,
#   'B-PER': 1.4210526315789474e-07,
#   'I-LOC': 1.4210526315789474e-07,
#   'I-MISC': 1.4210526315789474e-07,
#   'I-ORG': 1.4210526315789474e-07,
#   'I-PER': 1.4210526315789474e-07,
#   'O': 1.4210526315789474e-07},
#  'B-MISC': {'B-LOC': 1.4210526315789474e-07,
#   'B-MISC': 1.4210526315789474e-07,
#   'B-ORG': 1.4210526315789474e-07,
#   'B-PER': 1.4210526315789474e-07,
#   'I-LOC': 1.4210526315789474e-07,
#   'I-MISC': 0.5555555555555556,
#   'I-ORG': 1.4210526315789474e-07,
#   'I-PER': 1.4210526315789474e-07,
#   'O': 1.4210526315789474e-07},
#  'B-ORG': {'B-LOC': 1.4210526315789474e-07,
#   'B-MISC': 1.4210526315789474e-07,
#   'B-ORG': 1.4210526315789474e-07,
#   'B-PER': 1.4210526315789474e-07,
#   'I-LOC': 1.4210526315789474e-07,
#   'I-MISC': 1.4210526315789474e-07,
#   'I-ORG': 1.4210526315789474e-07,
#   'I-PER': 1.4210526315789474e-07,
#   'O': 0.75},
#  'B-PER': {'B-LOC': 1.4210526315789474e-07,
#   'B-MISC': 1.4210526315789474e-07,
#   'B-ORG': 1.4210526315789474e-07,
#   'B-PER': 1.4210526315789474e-07,
#   'I-LOC': 1.4210526315789474e-07,
#   'I-MISC': 1.4210526315789474e-07,
#   'I-ORG': 1.4210526315789474e-07,
#   'I-PER': 1.4210526315789474e-07,
#   'O': 1.4210526315789474e-07},
#  'I-LOC': {'B-LOC': 1.4210526315789474e-07,
#   'B-MISC': 1.4210526315789474e-07,
#   'B-ORG': 1.4210526315789474e-07,
#   'B-PER': 1.4210526315789474e-07,
#   'I-LOC': 1.4210526315789474e-07,
#   'I-MISC': 1.4210526315789474e-07,
#   'I-ORG': 1.4210526315789474e-07,
#   'I-PER': 1.4210526315789474e-07,
#   'O': 1.4210526315789474e-07},
#  'I-MISC': {'B-LOC': 1.4210526315789474e-07,
#   'B-MISC': 1.4210526315789474e-07,
#   'B-ORG': 1.4210526315789474e-07,
#   'B-PER': 1.4210526315789474e-07,
#   'I-LOC': 1.4210526315789474e-07,
#   'I-MISC': 1.4210526315789474e-07,
#   'I-ORG': 1.4210526315789474e-07,
#   'I-PER': 1.4210526315789474e-07,
#   'O': 1.4210526315789474e-07},
#  'I-ORG': {'B-LOC': 1.4210526315789474e-07,
#   'B-MISC': 1.4210526315789474e-07,
#   'B-ORG': 1.4210526315789474e-07,
#   'B-PER': 1.4210526315789474e-07,
#   'I-LOC': 1.4210526315789474e-07,
#   'I-MISC': 1.4210526315789474e-07,
#   'I-ORG': 1.4210526315789474e-07,
#   'I-PER': 1.4210526315789474e-07,
#   'O': 1.4210526315789474e-07},
#  'I-PER': {'B-LOC': 1.4210526315789474e-07,
#   'B-MISC': 1.4210526315789474e-07,
#   'B-ORG': 1.4210526315789474e-07,
#   'B-PER': 1.4210526315789474e-07,
#   'I-LOC': 1.4210526315789474e-07,
#   'I-MISC': 1.4210526315789474e-07,
#   'I-ORG': 1.4210526315789474e-07,
#   'I-PER': 1.4210526315789474e-07,
#   'O': 1.4210526315789474e-07},
#  'O': {'B-LOC': 1.4210526315789474e-07,
#   'B-MISC': 1.4210526315789474e-07,
#   'B-ORG': 0.06944444444444445,
#   'B-PER': 1.4210526315789474e-07,
#   'I-LOC': 1.4210526315789474e-07,
#   'I-MISC': 1.4210526315789474e-07,
#   'I-ORG': 1.4210526315789474e-07,
#   'I-PER': 1.4210526315789474e-07,
#   'O': 0.75},
#  'pi': {'B-LOC': 1.4210526315789474e-07,
#   'B-MISC': 0.2222222222222222,
#   'B-ORG': 0.2777777777777778,
#   'B-PER': 1.4210526315789474e-07,
#   'I-LOC': 1.4210526315789474e-07,
#   'I-MISC': 1.4210526315789474e-07,
#   'I-ORG': 1.4210526315789474e-07,
#   'I-PER': 1.4210526315789474e-07,
#   'O': 0.3333333333333333}}

# %%
int(is_Number('1'))
# Out:
# 1

# %%
#Important

# %%
flt_sentences = flatten_nested_lists(sentences_train)
flt_pos_tags = flatten_nested_lists(pos_tags_train)
flt_ner_tags = flatten_nested_lists(ner_tags_train)

feat,label,words = feature_extractor(flt_sentences,flt_pos_tags)

# %%
k=0
V=len(set(flatten_nested_lists(sentences_train)))
pp_sentences_train=preProcessIOBTagList(sentences_train)
pp_ner_tags_train=preProcessIOBTagList(ner_tags_train)

res =get_next_tag_prob(pp_sentences_train,pp_ner_tags_train,k,V)

# %%
def add_feature_templates():
    
    #cur_tag/prev_tag,cur_word
# Out:
# array([ 1.0000e+00,  0.0000e+00,  0.0000e+00,  5.7486e-01,  7.0326e-02,
#        -2.5808e-01,  3.2482e-01, -1.7873e-01, -7.2740e-01, -3.2019e-01,
#         7.3981e-02, -3.2846e-01, -8.5944e-01, -5.7321e-01,  7.6129e-01,
#        -3.3751e-02, -1.0564e-02,  1.0546e+00, -5.1391e-01, -4.2129e-01,
#        -2.6120e-01,  2.7952e-01,  7.8078e-02, -2.7215e-01,  1.2905e-01,
#         1.7239e-01, -4.9920e-03,  2.9988e-01, -3.6435e-01, -3.0291e-01,
#         4.6381e-01,  2.8826e-01,  4.4868e-02, -7.2278e-02,  2.6276e-01,
#         4.5824e-01,  1.3751e-01,  3.4337e-01, -1.8124e-02,  9.7508e-02,
#        -5.5806e-01, -2.0159e-01,  7.8213e-01,  4.1889e-01,  2.7571e-01,
#         6.6235e-01, -1.8328e-01,  6.1244e-01,  1.2024e-01,  1.1511e+00,
#        -6.2435e-02,  5.7438e-01,  9.3206e-01,  2.6103e-01, -9.1443e-03,
#        -3.0391e-01,  1.1360e-01,  1.3088e-02,  2.6707e-01,  1.7599e-01,
#        -8.3153e-01,  2.9613e-01,  1.7082e-01, -2.4875e-01, -2.7213e-02,
#         3.9247e-01,  6.3329e-01, -8.2152e-02,  6.0572e-01,  4.7111e-01,
#         1.3958e-02,  2.4046e-01,  2.1802e-01, -5.7058e-01,  1.3641e-02,
#        -4.0744e-01,  1.3109e-01,  9.3785e-01, -4.8046e-01,  1.8875e-01,
#        -4.2003e-01, -1.1640e-01, -1.5433e-01,  1.8783e-01,  3.5996e-02,
#         3.4223e-01, -5.6047e-02,  5.5919e-01, -6.9336e-01,  1.0238e-01,
#        -1.5987e+00, -4.2924e-02,  2.8146e-01, -4.6985e-02,  1.9038e-01,
#         2.8236e-01, -4.0561e-01,  3.3186e-01, -7.3804e-01, -4.8341e-02,
#         3.6356e-01, -2.5439e-02, -2.3440e-01, -2.3523e-01,  1.6204e-01,
#        -1.0818e-01, -5.7563e-01,  2.6651e-01,  5.2803e-01,  1.9977e-01,
#         2.3770e-01,  3.0211e-01,  1.4472e-01,  6.2419e-02,  7.8842e-02,
#         5.8746e-01,  1.9474e-01, -4.2676e-02,  1.7094e-01,  4.5576e-01,
#         2.9664e-01, -3.2228e-01, -3.7043e-01, -3.1954e-01,  3.1084e-01,
#        -3.5712e-01, -7.5145e-02,  7.4803e-01,  1.4361e-01, -2.9271e-02,
#         5.1477e-02,  6.0362e-02,  1.3399e-02, -1.5922e-01,  6.4954e-04,
#         3.5838e-01, -3.3932e-01, -2.2048e-01, -7.3875e-01, -3.8543e-01,
#        -6.5089e-02,  3.4384e-01,  8.3916e-02,  2.3003e-01,  3.7760e-01,
#         2.9972e-01, -2.1844e-01, -1.7448e-01,  9.0514e-02, -4.1279e-01,
#         7.0934e-02,  2.1538e-01,  1.6219e-01, -4.0691e-01,  4.7029e-01,
#        -3.7265e-01,  3.4750e-01, -7.9332e-03,  2.8079e-01, -1.1594e-01,
#         1.2926e-01,  1.5460e-03,  6.4879e-01, -2.6279e-01, -3.0611e-01,
#         1.1231e-01, -1.4111e-01, -6.2248e-01,  2.9015e-01,  1.3776e-02,
#        -8.5401e-01,  1.7075e-01,  2.0493e-01, -3.4190e-01, -4.0794e-01,
#         2.2147e-01, -3.7881e-01,  3.0843e-01,  5.4492e-01,  1.3855e-01,
#         5.1207e-01,  3.2519e-01,  9.0449e-01, -3.8777e-01,  1.6902e-01,
#        -1.8531e-01, -1.9376e-01, -7.3098e-02, -5.2756e-02,  2.1556e-01,
#         1.6113e-01,  5.1360e-02,  1.0378e-02,  3.4078e-01,  9.1789e-02,
#         4.9896e-01, -2.5009e-01, -8.6312e-02, -1.0974e+00,  1.9808e-01,
#        -7.3605e-02,  1.0865e-01, -2.7475e-01,  4.2865e-01,  8.7587e-01,
#         5.2599e-01,  1.0734e-01,  3.2811e-01,  3.7885e-01,  2.9466e-01,
#        -3.0564e-01,  1.1852e-01,  6.2243e-01, -1.4899e-01,  1.3584e-01,
#        -5.3631e-01,  5.4322e-01,  8.8134e-03, -1.2954e-02, -5.1974e-02,
#        -1.5882e+00,  1.7206e-02,  5.9023e-01, -9.5288e-02,  3.0071e-01,
#         5.9304e-01, -4.2209e-01,  4.5872e-01, -3.8220e-01, -4.4472e-01,
#         6.7452e-01,  1.3761e-01,  6.5528e-02,  3.5187e-01,  4.2685e-01,
#         1.9570e-01, -3.7357e-01,  4.3601e-01, -1.3014e-01,  1.5501e-01,
#         3.9692e-01,  5.5351e-02,  1.8814e-01,  1.2797e-01, -1.6142e-01,
#         2.5297e-01, -2.1300e-01,  3.3804e-01,  2.5964e-01,  1.1240e-01,
#        -2.4421e-01, -1.2917e-01, -2.2393e-03,  3.6422e-01,  1.2193e-01,
#         2.8636e-01, -5.8876e-01,  2.1928e-03, -2.2194e-01,  3.5243e-01,
#         3.7727e-01,  1.1737e-01,  5.9135e-01, -2.8581e-01,  5.7555e-01,
#        -5.8530e-02,  4.1154e-01,  4.8270e-01,  7.0858e-02, -2.9040e-01,
#         1.2072e-02,  2.7351e-01,  7.4096e-02, -7.2568e-01,  1.6824e-01,
#        -1.9424e-01,  1.6639e-01,  2.9643e-01,  9.1598e-03,  7.9244e-02,
#         1.8496e-01,  5.9475e-02, -1.5095e-01,  2.6140e-01, -2.2552e-01,
#        -9.1786e-02,  5.2772e-01, -3.3878e-01,  4.8127e-02, -4.7371e-02,
#        -3.4435e-01, -3.9698e-01,  2.3125e-01, -3.2468e-01, -3.0512e-01,
#        -5.0477e-01, -6.8525e-01,  1.4128e-01,  4.1040e-01,  3.7868e-02,
#        -7.2195e-02, -2.8299e-01,  9.7629e-03])

# %%
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression(random_state=0, solver='lbfgs',multi_class='multinomial').fit(X, y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-396-d9af4867572b> in <module>()
#       1 from sklearn.linear_model import LogisticRegression
# ----> 2 clf = LogisticRegression(random_state=0, solver='lbfgs',multi_class='multinomial').fit(X, y)
#
# NameError: name 'X' is not defined

# %% [markdown]
# # Again

# %%
def get_unique(lst):
    result = []
    for item in lst:
        if item not in result:
            result+=item
    return result

# %%
from nltk.util import ngrams
import nltk

# %%
flt_ner_tags_train=flatten_nested_lists(ner_tags_train)

# %%
#Kn for trigram
train_tags_triigrm = list(nltk.trigrams(flt_ner_tags_train))
freq_dist = nltk.FreqDist(train_tags_triigrm)
kneser_ney = nltk.KneserNeyProbDist(freq_dist)
print(len(set(train_tags_bigrm)))
# Out:
# 52

# %%
# Out:
# 0.0

# %% [markdown]
# # Generate test output

# %%
#result = { PER : [] }
def gen_tag_indexes(pred):
    result = defaultdict(list)
    T = len(pred)
    for i in range(len(pred)):
        
        if 'B-' in pred[i]:
            flag=1;
            tag_type = pred[i][2:]
            j=i+1
            while j<T and (pred[j] == 'I-'+tag_type) :
                j=j+1             
                
            j=j-1 #To get to last token
            result[tag_type].append(str(i)+'-'+str(j))
            #if i==j:
            #    result[tag_type].append(str(i))       
            #else:
            #    result[tag_type].append(str(i)+'-'+str(j))
    return result

# %%
word_test
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-526d835e34b7> in <module>()
# ----> 1 word_test
#
# NameError: name 'word_test' is not defined

# %%
pred=['B-PER','B-PER','I-PER','B-LOC','O','O','O','B-MISC', 'I-MISC','I-LOC']

# %%
a= gen_tag_indexes(pred)

# %%
' '.join(a['PER'])
# Out:
# '0 1-2'

# %% [markdown]
# # Create Excel for Kaggle

# %%
def write_result(filename,preds):
    with open(filename, 'w') as csvfile:
        filewriter = csv.writer(csvfile, delimiter=',',
                                quotechar='|', quoting=csv.QUOTE_MINIMAL)
        filewriter.writerow(['Type','Prediction'])
        
        filewriter.writerow(['ORG',' '.join(preds['ORG'])])
        filewriter.writerow(['MISC',' '.join(preds['MISC'])])
        filewriter.writerow(['PER',' '.join(preds['PER'])])
        filewriter.writerow(['LOC',' '.join(preds['LOC'])])

# %%
write_result('temp.csv', a)
